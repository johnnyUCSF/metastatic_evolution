# %% [markdown]
# # 032018 JY Metastatic Evolution Analysis

# %% [markdown]
# # Section 1, read in and format data.

# %%
import pandas as pd
import os 
import numpy as np
import scipy as sp
import scipy.stats as stats
import Bio
import rpy2
# %load_ext rpy2.ipython

# %%
###################format 10Xbarcodes:GeneticBC into table suitable for R
###define filenames
name_parental = '10XBC_to_geneticBC/CTAA_outfile.txt'
name_lvm1 = '10XBC_to_geneticBC/CACG_outfile.txt'
name_lvm2 = '10XBC_to_geneticBC/GGTT_outfile.txt'
name_allbarcodes = '../barcodes/barcodes.tsv'
###read in files to lists
with open(name_parental) as f:
    Parent = f.read().splitlines()
with open(name_lvm1) as f:
    Lvm1 = f.read().splitlines()
with open(name_lvm2) as f:
    Lvm2 = f.read().splitlines()
with open(name_allbarcodes) as f:
    AllBC = f.read().splitlines()
###format allBC list
new = []
for barcode in AllBC:
    new.append(barcode[:-2])
AllBC = new
###filter unmatched barcodes; as in barcodes without matched genetic barcodes
nomatch_BCs = list(set(AllBC)-set(Parent)-set(Lvm1)-set(Lvm2))
###
combined = []
barcodes = []
ids = []
is_matching = []
for barcode in Parent:
    barcodes.append(barcode)
    ids.append('Parent')
    is_matching.append('Y')
for barcode in Lvm1:
    barcodes.append(barcode)
    ids.append('Lvm1')
    is_matching.append('Y')
for barcode in Lvm2:
    barcodes.append(barcode)
    ids.append('Lvm2')
    is_matching.append('Y')
for barcode in nomatch_BCs:
    barcodes.append(barcode)
    ids.append('NA')
    is_matching.append('N')
combined.append(barcodes)
combined.append(ids)
combined.append(is_matching)
###write to final dataframe, sort alphabetically
final = pd.DataFrame(data=combined).T
final.sort_values(by=0,inplace=True)
final.head()
# Out:
#                      0       1  2
# 6455  AAACCTGAGCTGCAAG    Lvm2  Y
# 8592  AAACCTGAGGAATGGA      NA  N
# 7524  AAACCTGAGGGCTCTC    Lvm2  Y
# 460   AAACCTGCAACGATCT  Parent  Y
# 5067  AAACCTGCAATCAGAA    Lvm2  Y

# %%
###########format barcodes generated from 10X run and sort annotation dataframe to match order of 10X reporting
name_BC10X = '../cellranger_output/outs/filtered_gene_bc_matrices/GRCh38/barcodes.tsv'
###
new = []
with open(name_BC10X) as f:
    BC10X = f.read().splitlines()
for barcode in BC10X:
    new.append(barcode[:-2])
BC10X = new
###test to see if the order matches
test = final[0].tolist()
print("Do these lists match?",test == BC10X)
###write to file
final.to_csv('io/ColData_for_R.tsv',sep='\t',header=None,index=None)
# Out:
# ('Do these lists match?', True)

# %%
# %%R
#
# require("Matrix")
# library(SingleCellExperiment)
# #######read in 10X generated files
# cellbarcodes <- read.table("../cellranger_output/outs/filtered_gene_bc_matrices/GRCh38/barcodes.tsv")
# genenames <- read.table("../cellranger_output/outs/filtered_gene_bc_matrices/GRCh38/genes.tsv")
# molecules <- Matrix::readMM("../cellranger_output/outs/filtered_gene_bc_matrices/GRCh38/matrix.mtx")
# #######format
# rownames(molecules) <- genenames[,1]
# colnames(molecules) <- cellbarcodes[,1]
# #######read in and format ColData metadata file processed in python from above
# meta <- read.table('io/ColData_for_R.tsv',sep='\t')
# colnames(meta) <- c('barcode','sample','is_matched')
# #######format and read into singlecellexperiment object
# molecules <- as.matrix(molecules)
# meta <- as.data.frame(meta)
# #######
# scdata <- SingleCellExperiment(assays = list(counts = molecules),colData=meta)
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Matrix
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: SummarizedExperiment
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomicRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: stats4
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocGenerics
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:Matrix’:
#
#     colMeans, colSums, rowMeans, rowSums, which
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rowMeans, rownames, rowSums, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which, which.max, which.min
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: S4Vectors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘S4Vectors’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:Matrix’:
#
#     expand
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: IRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomeInfoDb
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Biobase
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: DelayedArray
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: matrixStats
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘matrixStats’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘DelayedArray’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     apply
#
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
#
# library(SingleCellExperiment)
# library(scater)
# library(scran)
# options(stringsAsFactors = FALSE)
# gc()
# ###########################BEGIN CELL FILTERING###################
# keep_feature <- rowSums(counts(scdata) > 0) > 0
# scdata <- scdata[keep_feature, ]
# ####### do calculations
# logcounts(scdata) <- log2(calculateCPM(scdata, use.size.factors = FALSE) + 1)
# tpm(scdata) <- calculateTPM(scdata, effective_length = 5e4)
# cpm(scdata) <- calculateCPM(scdata, use.size.factors = FALSE)
# ####metrics
# scdata <- calculateQCMetrics(scdata)
#
# ##filter total counts
# cutoff_reads = 35000
# ##plot total counts
# hist(
#     scdata$total_counts,
#     breaks = 25
# )
# abline(v = cutoff_reads, col = "red")
# ###cutoff by total counts
# filter_by_total_counts <- (scdata$total_counts < cutoff_reads)
# print(table(filter_by_total_counts))
# ##filter total features
# cutoff_features = 2000
# ##plot total features (genes)
# hist(
#     scdata$total_features,
#     breaks = 25
# )
# abline(v = cutoff_features, col = "red")
# ###cutoff by total features
# filter_by_expr_features <- (scdata$total_features > cutoff_features)
# print(table(filter_by_expr_features))
# #######filter by total counts, total features
# ### sufficient features (genes)
# ### sufficient molecules counted
# scdata$use <- (filter_by_expr_features & filter_by_total_counts)
# print('number remaining:')
# print(sum(scdata$use,na.rm=TRUE))
# ###########################END CELL FILTERING###################
# ###########################BEGIN CELL CYLCE FILTERING###################
# hg.pairs <- readRDS(system.file("exdata", "human_cycle_markers.rds", package="scran"))
# assigned <- cyclone(scdata, pairs=hg.pairs)
# colData(scdata)$phase <- assigned$phases
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Use suppressPackageStartupMessages() to eliminate package startup
# messages.
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘scater’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:stats’:
#
#     filter
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocParallel
#
#   warnings.warn(x, RRuntimeWarning)
# filter_by_total_counts
# FALSE  TRUE
#   317  9242
# filter_by_expr_features
# FALSE  TRUE
#   131  9428
# [1] "number remaining:"
# [1] 9111

# %%
# %%R
#
# ###########################BEGIN GENE FILTERING###################
# ###filter number of cells each gene has to be at minimum present in
# cutoff_numcells = 3
# ###filter genes whose absolute counts are at least > 1 and present in at least (cutoff_numcell) # of cells
# filter_genes <- apply(
#     counts(scdata[ , colData(scdata)$use]),
#     1,
#     function(x) length(x[x > 1]) >= cutoff_numcells
# )
# rowData(scdata)$use <- filter_genes
# print(table(filter_genes))
# ###save data
# dim(scdata[rowData(scdata)$use, colData(scdata)$use])
# saveRDS(scdata, file = "scater/filtered.rds")
# Out:
# filter_genes
# FALSE  TRUE
#  9695 13311

# %%
# %%R
#
# ##############plot genes with highest counts
#
# ###plot
# plotQC(scdata, type = "highest-expression")

# %% [markdown]
# # Section 2, basic visualization of technical bias and QC

# %%
# %%R
# ######################################################################
# library(SingleCellExperiment)
# library(scater)
# library(scran)
# options(stringsAsFactors = FALSE)
# gc()
# ###readin
# scdata <- readRDS("scater/filtered.rds")
# ###subset by is_matched
# test <- scdata[ , colData(scdata)$is_matched=='Y']
# ###subset by qc'd
# scdata.qc <- test[rowData(test)$use, colData(test)$use]
# ###save
# saveRDS(scdata.qc, file = "scater/scdata_qc.rds")

# %%
# %%R
# #############see all features
# ###plot PCA
#
# plotPCA(
#     scdata.qc,
#     exprs_values = "logcounts",
#     colour_by = "sample",
#     size_by = "total_features",
#     shape_by = "phase",
#     draw_plot=TRUE,
#     return_SCE=FALSE,
#     ncomponents = 2
# )

# %%
# %%R
# #############see only sample feature
# ###plot PCA
#
# plotPCA(
#     scdata.qc,
#     exprs_values = "logcounts",
#     colour_by = "sample",
#     draw_plot=TRUE,
#     return_SCE=FALSE,
#     ncomponents = 2
# )

# %%
# %%R
# ####################################################################
# ####################################################################
# ###plot PCA
#
# plotPCA(
#     scdata.qc,
#     exprs_values = "logcounts",
#     colour_by = "total_features",
#     draw_plot=TRUE,
#     return_SCE=FALSE,
#     ncomponents = 2
# )

# %%
# %%R
#
# ###plot TSNE
#
# plotTSNE(
#     scdata.qc,
#     perplexity = 30,
#     rand_seed = 123456,
#     exprs_values = "logcounts",
#     colour_by = "sample",
#     draw_plot=TRUE,
#     return_SCE=FALSE
# )

# %%
# %%R
#
# ###find covariate correlation with PC using default method (logcounts(cpm))
#
# plotQC(
#     scdata.qc,
#     type = "find-pcs",
#     exprs_values = "logcounts",
#     variable = "total_features"
# )

# %%
# %%R
#
# ###find explanatory variables
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "logcounts",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %%
# %%R
#
# ###find explanatory variables
#
# plotRLE(
#     scdata.qc,
#     exprs_mats = list(cpm = "logcounts"),
#     exprs_logged = c(TRUE, TRUE),
#     colour_by = "sample"
# )

# %% [markdown]
# Very high correlation of total features with variance. Need to correct using method other than default method (logcounts(cpm)). Testing different correction methods.

# %% [markdown]
# correct using upper quartile method

# %%
# %%R
#
# ###bias correction with upperquartile method
#
# scdata.qc <- normaliseExprs(
#     scdata.qc,
#     method = "upperquartile",
#     p = 0.99,
#     return_log = TRUE,
#     return_norm_as_exprs = FALSE
# )
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "norm_exprs",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %% [markdown]
# correct using RLE method

# %%
# %%R
#
# ###bias correction with RLE method
#
# scdata.qc <- normaliseExprs(
#     scdata.qc,
#     method = "RLE",
#     return_log = TRUE,
#     return_norm_as_exprs = FALSE
# )
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "norm_exprs",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %% [markdown]
# correct using TMM method

# %%
# %%R
#
# ###bias correction using TMM
#
# scdata.qc <- normaliseExprs(
#     scdata.qc,
#     method = "TMM",
#     return_log = TRUE,
#     return_norm_as_exprs = FALSE
# )
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "norm_exprs",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %% [markdown]
# correct using scran

# %%
# %%R
#
# ###bias correction using scran
#
# scdata.qc <- computeSumFactors(scdata.qc)
# scdata.qc <- normalize(scdata.qc)
#
# scdata.qc
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "logcounts",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %% [markdown]
# RLE looks like best correction method for library size, use for full dataset.

# %%
# %%R
#
# ######################################################################
# library(SingleCellExperiment)
# library(scater)
# library(scran)
# options(stringsAsFactors = FALSE)
# gc()
# ###readin
# scdata.qc <- readRDS("scater/scdata_qc.rds")
# cpm(scdata) <- log2(calculateCPM(scdata, use.size.factors = FALSE) + 1)
# ###normalization stored in "norm_exprs" slot
# scdata.qc <- normaliseExprs(
#     scdata.qc,
#     method = "RLE",
#     return_log = TRUE,
#     return_norm_as_exprs = FALSE
# )
#
# ###save file
# saveRDS(scdata.qc, file = "scater/norm_exprs.rds")

# %% [markdown]
# Check gene variance

# %%
# %%R
#
# ###check gene variance
# library(SingleCellExperiment)
# library(scater)
# library(scran)
# options(stringsAsFactors = FALSE)
# gc()
# ###readin
# scdata.qc <- readRDS("scater/norm_exprs.rds")
# ###
# fit <- trendVar(logcounts(scdata.qc))
# decomp <- decomposeVar(logcounts(scdata.qc), fit)
# top.hvgs <- order(decomp$bio, decreasing=TRUE)
# print(head(decomp[top.hvgs,]))
#
#
# plot(decomp$mean, decomp$total, xlab="Mean log-expression", ylab="Variance")
# o <- order(decomp$mean)
# points(fit$mean, fit$var, col="blue", pch=0.5)
# lines(decomp$mean[o], decomp$tech[o], col="red", lwd=2)
# Out:
#                     mean    total      bio      tech p.value FDR
# ENSG00000104371 1.609634 3.617302 2.894593 0.7227089       0   0
# ENSG00000197061 3.155706 3.415476 2.716613 0.6988635       0   0
# ENSG00000175063 1.917380 2.687527 1.955490 0.7320368       0   0
# ENSG00000124205 1.930602 2.531362 1.798919 0.7324428       0   0
# ENSG00000173432 1.187296 2.384653 1.700525 0.6841286       0   0
# ENSG00000163453 2.836124 2.316143 1.610104 0.7060389       0   0

# %% [markdown]
# correct batch effects due to cell cycle stage, as defined previously by cyclone function

# %%
# %%R
#
# ###baseline
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "norm_exprs",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %%
# %%R
#
# ###bias correction using combat
# library(sva)
#
# combat_data <- norm_exprs(scdata.qc)
#
# mod_data <- as.data.frame(t(combat_data))
#
# mod0 = model.matrix(~ 1, data = mod_data)
#
# mod1 = model.matrix(~ scdata.qc$sample, data = mod_data)
#
# mod2 = model.matrix(~ scdata.qc$total_features, data = mod_data)
#
# assay(scdata.qc, "combat") <- ComBat(
#     dat = t(mod_data),
#     batch = factor(scdata.qc$phase),
#     mod = mod0,
#     par.prior = TRUE,
#     prior.plots = FALSE
# )
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "combat",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: mgcv
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: nlme
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘nlme’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:IRanges’:
#
#     collapse
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: This is mgcv 1.8-22. For overview type 'help("mgcv-package")'.
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: genefilter
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘genefilter’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     rowSds, rowVars
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Found3batches
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Adjusting for0covariate(s) or covariate level(s)
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Fitting L/S model and finding priors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Finding parametric adjustments
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Adjusting the Data
#
#
#   warnings.warn(x, RRuntimeWarning)
# Standardizing Data across genes

# %%
# %%R
#
# ###bias correction using generalized linear model
#
# glm_fun <- function(g, batch, indi) {
#   model <- glm(g ~ batch + indi)
#   model$coef[1] <- 0 # replace intercept with 0 to preserve reference batch.
#   return(model$coef)
# }
# effects <- apply(
#     norm_exprs(scdata.qc),
#     1,
#     glm_fun,
#     batch = scdata.qc$phase,
#     indi = scdata.qc$sample
# )
# corrected <- logcounts(scdata.qc) - t(effects[as.numeric(factor(scdata.qc$phase)), ])
# assay(scdata.qc, "glm") <- corrected
#
# plotQC(
#     scdata.qc,
#     type = "expl",
#     exprs_values = "glm",
#     variables = c(
#         "total_features",
#         "total_counts",
#         "sample",
#         "phase"
#     )
# )

# %% [markdown]
# comBat seems best, correct using that model.

# %%
# %%R
#
# ###bias correction using combat
# library(sva)
#
# combat_data <- norm_exprs(scdata.qc)
#
# mod_data <- as.data.frame(t(combat_data))
#
# mod0 = model.matrix(~ 1, data = mod_data)
#
# mod1 = model.matrix(~ scdata.qc$sample, data = mod_data)
#
# mod2 = model.matrix(~ scdata.qc$total_features, data = mod_data)
#
# assay(scdata.qc, "normcounts") <- ComBat(
#     dat = t(mod_data),
#     batch = factor(scdata.qc$phase),
#     mod = mod0,
#     par.prior = TRUE,
#     prior.plots = FALSE
# )
#
# ###save file
# saveRDS(scdata.qc, file = "scater/cell_phase_normd.rds")
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: mgcv
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: nlme
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘nlme’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:IRanges’:
#
#     collapse
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: This is mgcv 1.8-22. For overview type 'help("mgcv-package")'.
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: genefilter
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘genefilter’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     rowSds, rowVars
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocParallel
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Found3batches
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Adjusting for0covariate(s) or covariate level(s)
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Fitting L/S model and finding priors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Finding parametric adjustments
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Adjusting the Data
#
#
#   warnings.warn(x, RRuntimeWarning)
# Standardizing Data across genes

# %%
# %%R
# ###
# library(SingleCellExperiment)
# library(scater)
# library(SC3)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata.qc <- readRDS("scater/cell_phase_normd.rds")
# ###write
# write.csv(head(logcounts(scdata.qc)),'before.tsv',sep='\t')
# write.csv(head(normcounts(scdata.qc)),'combat.tsv',sep='\t')
# logcounts(scdata.qc) <- normcounts(scdata.qc)
# write.csv(head(logcounts(scdata.qc)),'after.tsv',sep='\t')
# ###save file
# saveRDS(scdata.qc, file = "scater/cell_phase_normd.rds")
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: SummarizedExperiment
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomicRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: stats4
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocGenerics
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rowMeans, rownames, rowSums, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which, which.max, which.min
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: S4Vectors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘S4Vectors’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: IRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomeInfoDb
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Biobase
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: DelayedArray
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: matrixStats
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘matrixStats’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘DelayedArray’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     apply
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘scater’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:stats’:
#
#     filter
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# # THIS FILE MOVED OVER TO PIPELINE 2 FOR VISUALIZATION
# "scater/cell_phase_normd.rds"

# %% [markdown]
# # At this point, moved over to pipeline_1 for processing
# that file was saved as 'ready_for_clustering.rds'

# %% [markdown]
# # Section 3, biological analysis

# %% [markdown]
# # Cluster together - P, LVM1, LVM2

# %% [markdown]
# cluster with SC3 v = 1.7.7

# %%
# %%R
#
# ###
# library(SingleCellExperiment)
# library(scater)
# library(SC3)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata <- readRDS("scater/ready_for_clustering.rds")
# ###
# rowData(scdata)$feature_symbol <-rownames(scdata)
# ####cluster
# scdata <- sc3(scdata, ks = 9:10, biology = TRUE,n_cores=16)
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: SummarizedExperiment
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomicRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: stats4
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: BiocGenerics
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rowMeans, rownames, rowSums, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which, which.max, which.min
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: S4Vectors
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘S4Vectors’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: IRanges
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: GenomeInfoDb
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: Biobase
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: DelayedArray
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: matrixStats
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘matrixStats’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘DelayedArray’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:base’:
#
#     apply
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘scater’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:stats’:
#
#     filter
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Setting SC3 parameters...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Your dataset contains more than 2000 cells. Adjusting the nstart parameter of kmeans to 50 for faster performance...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Defining training cells for SVM using 5000 random cells...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Calculating distances between the cells...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Performing transformations and calculating eigenvectors...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Performing k-means clustering...
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# # THIS FILE MOVED OVER TO PIPELINE 2 FOR VISUALIZATION
# "scater/sc3_clustered.rds"

# %%
# %%R
# ####because they are using sampling on cells = 5000, we have to use SVM to recluster based on training set of 5000
# scdata <- sc3_run_svm(scdata, ks = 9:10)
# col_data <- colData(scdata)
# head(col_data[ , grep("sc3_", colnames(col_data))])
# ####recalculate biology
# metadata(scdata)$sc3$svm_train_inds <- NULL
# scdata <- sc3_calc_biology(scdata, ks = 10)
# ###save file
# saveRDS(scdata, file = "scater/sc3_clustered.rds")

# %% [markdown]
# Briefly visualize

# %%
# %%R
#
# ###plot TSNE
#
# plotTSNE(
#     scdata,
#     colour_by = "sample"
# )

# %%
# %%R
#
# ###plot TSNE
#
# plotTSNE(
#     scdata,
#     colour_by = "sc3_10_clusters"
# )

# %% [markdown]
# Recluster with higher k

# %% [markdown]
# # THIS FILE MOVED OVER TO PIPELINE 2 FOR VISUALIZATION
# "scater/sc3_clustered_20to40.rds"

# %%
# %%R
#
# ###
# library(SingleCellExperiment)
# library(scater)
# library(SC3)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata <- readRDS("scater/ready_for_clustering.rds")
# ###
# rowData(scdata)$feature_symbol <-rownames(scdata)
# ####cluster
# scdata <- sc3(scdata, ks = 20:40, biology = TRUE,n_cores=16)
# ###save file
# saveRDS(scdata, file = "scater/sc3_clustered_20to40.rds")

# %% [markdown]
# plot correlation heatmaps for different cluster sizes

# %%
# %%R
#
# sc3_plot_consensus(scdata, k = 35, show_pdata = "sample")

# %% [markdown]
# plot silhouttes for different cluster sizes

# %%
# %%R
#
# sc3_plot_silhouette(scdata, k = 35)

# %% [markdown]
# plot expression heatmap for different cluster sizes

# %%
# %%R
#
# sc3_plot_expression(scdata, k = 35, show_pdata = "sample")

# %% [markdown]
# Silhoutte analysis showed 3,6,10 clusters seemed best for the data. Saving figures for these clusters.

# %% [markdown]
# # Use TSCAN for pseudotime analysis

# %%
# %%R
#
# ###
# library(SingleCellExperiment)
# library(scater)
# library(TSCAN)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata <- readRDS("scater/ready_for_clustering.rds")

# %%
# %%R
# ###subset, use logcounts as input (cleaned, etc)
# scdata <- data.frame(logcounts(scdata))
# ###
# colnames(procdata) <- 1:ncol(scdata)
# clust <- TSCAN::exprmclust(scdata, clusternum = 2:20)
# TSCAN::plotmclust(clust)
# Out:
# fitting ...
#   |======================================================================| 100%

# %%
# %%R
#
# ###save file
# saveRDS(clust, file = "TSCAN/TSCAN_clust.rds")

# %%
# %%R
#
# TSCAN::plotmclust(clust, show_cell_names = F)

# %%
# %%R
#
#  clust_order <- TSCANorder(clust)

# %%
# %%R
#
# head(clust, n=5)
# Out:
# $pcareduceres
#                              PC1           PC2           PC3           PC4
# AAACCTGAGCTGCAAG.1  2.883508e+00  -9.608374356   2.943434965 -5.511763e+00
# AAACCTGAGGGCTCTC.1 -2.961680e+01 -12.335632441   0.214597673 -5.487330e+00
# AAACCTGCAACGATCT.1  1.430024e+00   1.999535928  13.214923498  7.191797e+00
# AAACCTGCAATCAGAA.1 -1.528474e+01  -7.971931876  12.188013994  9.694311e+00
# AAACCTGCAATGGATA.1 -9.285149e+00  -6.231241691  -6.877392813  2.533384e+00
# AAACCTGCACGCTTTC.1  1.264048e+01 -19.058690264   0.553861501 -4.262161e+00
# AAACCTGGTAAAGTCA.1 -3.718936e+00  14.012576159  -0.600238597 -6.305030e+00
# AAACCTGGTAGCACGA.1 -1.948909e+01  -1.546748059   7.186327036  5.189714e+00
# AAACCTGGTAGCTAAA.1 -3.313292e+00  13.551298114   1.873895386 -2.291824e+00
# AAACCTGTCAGCTGGC.1 -2.331525e+01 -14.182095441   8.455505500  5.101014e+00
# AAACCTGTCGTTACAG.1  1.360359e+01  -7.698439081   3.962359344 -5.794978e+00
# AAACCTGTCTTAGCCC.1 -1.910778e+01 -12.621894302  -5.635378332  8.156648e-01
# AAACGGGAGAGATGAG.1 -9.283040e+00 -10.509467355  -0.862257967 -1.443423e+01
# AAACGGGAGTTAACGA.1 -1.568930e+01  12.609279888  -2.316364015 -3.222919e+00
# AAACGGGAGTTGAGTA.1  1.137396e+01  13.100213886   7.851920511 -2.005304e+00
# AAACGGGCAAGGGTCA.1 -8.076625e+00  -4.937728814  17.213789355 -2.079905e+00
# AAACGGGCAAGTAATG.1 -2.139183e+01  -0.874780626   0.375355949 -7.890871e+00
# AAACGGGCACAACTGT.1  1.172500e+01 -10.833319295 -10.295931327 -4.557621e+00
# AAACGGGCAGATGGCA.1  1.837183e+01   7.830201475  15.182704170  1.711104e+01
# AAACGGGCATGAAGTA.1 -1.123944e+01  -5.485248452   2.438378297 -1.365520e+00
# AAACGGGGTACACCGC.1 -7.525724e+00 -10.338657214   2.215813359 -1.435209e+00
# AAACGGGGTCGACTAT.1  1.114271e+01   1.357414833 -16.408768220 -3.126062e+00
# AAACGGGGTGTTGAGG.1  3.215448e+01   6.701161909   6.534738436  9.272244e+00
# AAACGGGGTTGCGTTA.1  1.154522e+01  -0.419695231 -21.993621821  2.737437e+00
# AAACGGGGTTGGTTTG.1  1.123615e+01  -0.639406471   4.907913835 -4.707770e+00
# AAACGGGTCCGATATG.1  5.785491e-01  -8.200873464  -2.313955141  2.222292e+00
# AAACGGGTCTCGAGTA.1  1.628764e+01 -23.384532135   5.266964738 -5.506828e+00
# AAACGGGTCTCTGTCG.1 -2.542772e+01   1.087727472  12.931279028  6.406374e+00
# AAACGGGTCTGTCAAG.1 -4.924051e+00  13.655879908   7.466530685  3.906275e-02
# AAAGATGAGAATCTCC.1 -1.546010e+01 -16.031712876 -16.152411585  1.387321e+01
# AAAGATGAGGAACTGC.1 -9.604771e+00  -4.627371702   5.922067651 -4.293265e+00
# AAAGATGAGGCATGTG.1  1.178408e+01   5.824516200  13.336383684 -8.184667e+00
# AAAGATGAGTATCGAA.1  3.969696e+00 -10.671016709  12.077637282  1.946348e+00
# AAAGATGAGTGCCAGA.1  1.308368e+01 -21.685686524 -12.257770364  1.477337e+01
# AAAGATGCACGTTGGC.1 -2.156177e+01   0.159259907   8.764830671 -7.153694e+00
# AAAGATGCATGAGCGA.1 -1.138593e+01  -9.052655748  -0.490633307 -6.428651e+00
# AAAGATGGTCCCTTGT.1  1.502957e+00 -20.194655901  -1.803432435 -1.824744e+00
# AAAGATGGTGTTTGTG.1 -1.719294e+01  -0.671222890   3.930255925 -8.507969e+00
# AAAGATGGTTACCGAT.1  2.680089e+01  -9.757562896 -12.421400022  2.564203e+00
# AAAGATGTCATCTGTT.1 -2.033296e+01   1.840244534  -2.150695818 -3.778510e-01
# AAAGATGTCGTCTGCT.1  1.165635e+01   8.958496564 -16.517888692  4.457535e+00
# AAAGATGTCTAACTCT.1  1.268478e+01   0.617564875  14.257878288  5.957820e+00
# AAAGATGTCTCGATGA.1 -9.734134e+00 -10.275081451   9.889676262  8.943169e+00
# AAAGATGTCTGTCCGT.1  6.726022e+00   5.108958213  -4.116367276  3.452353e+00
# AAAGATGTCTTAACCT.1 -5.459074e+00  -3.717441403   5.372064182 -8.528057e+00
# AAAGATGTCTTTACGT.1 -1.026097e+01  -0.957991672   3.645518176 -5.728834e+00
# AAAGCAAAGCAATATG.1  2.516862e+01 -15.806754558  -2.207394209  1.480450e+01
# AAAGCAAAGCGAAGGG.1 -1.001492e+01   1.593964488  11.261662897 -1.141588e+01
# AAAGCAAAGTCCCACG.1  5.591097e+00  -7.772064492  13.371405142 -5.808302e+00
# AAAGCAAAGTGACTCT.1 -1.465120e+01   2.741511183   2.369580866 -4.806696e+00
# AAAGCAAAGTGCGATG.1 -3.300749e-01  15.407458937  -0.826873020  1.807072e+00
# AAAGCAAAGTGGTAGC.1  6.159476e+00  -9.396365165  17.417322268  6.344726e+00
# AAAGCAACAAGAGTCG.1 -4.825185e+00   4.946097083  -5.137947686 -4.403193e+00
# AAAGCAACAATAGCAA.1 -2.644601e+01   0.014429250   6.584700990  4.882284e+00
# AAAGCAACACATCTTT.1  1.487034e+01  -7.860693540   6.685636501 -2.662115e+00
# AAAGCAACAGTAGAGC.1 -1.444167e+01  15.942272925  -2.602778412 -6.254667e+00
# AAAGCAACATTGGTAC.1  5.351277e+00  -9.666536996   9.595206286  2.312758e+01
# AAAGCAAGTAAGAGAG.1  7.222394e+00  -2.814564956   3.484894247 -3.178796e+00
# AAAGCAAGTAGTACCT.1 -1.941908e+01  -2.762809810  12.505876291 -3.925389e+00
# AAAGCAAGTCAACATC.1  1.754458e+01 -14.836420583 -19.393708979  5.293078e+00
# AAAGCAAGTGTGAATA.1  5.865712e+00  -2.907782879   2.550315765 -1.441755e+01
# AAAGCAATCACGACTA.1 -1.601904e+01 -12.078523223   3.734626024 -6.701220e+00
# AAAGCAATCAGAGCTT.1  7.445659e-01  -9.146452248  -2.633457174  4.009792e+00
# AAAGCAATCCACGACG.1  4.240117e+00  10.818975859   1.389269494  3.513062e+00
# AAAGTAGAGAGTAAGG.1 -4.745255e+00  -3.700160447   9.819606039  5.463458e+00
# AAAGTAGAGCAATCTC.1  2.658292e+00  -9.774282037 -11.291150746  6.357568e-01
# AAAGTAGAGGGTCGAT.1  1.391907e+01   3.337859262  14.207387607 -4.045824e+00
# AAAGTAGAGTCCAGGA.1  1.369912e+01  -9.083133505  -0.068283384 -8.917570e+00
# AAAGTAGCAAGCCGTC.1 -1.958922e+01  24.580044811   1.747398933 -2.659809e+00
# AAAGTAGCAGCTCGCA.1 -7.648236e+00  -4.388466932   8.421061047  6.142307e+00
# AAAGTAGCATCATCCC.1 -2.722549e+00  11.901364301  -7.169923198 -1.595998e+00
# AAAGTAGGTACAGACG.1 -1.173565e+01  -3.573411194  -5.888367993 -6.020149e+00
# AAAGTAGGTCAGAGGT.1  1.173708e+01  -8.986039328   4.098049877 -8.507022e+00
# AAAGTAGGTCCATGAT.1  3.874542e+00  11.123666794 -11.041493582 -4.114130e+00
# AAAGTAGGTCCGTCAG.1  1.727519e+01  -4.053065389 -18.559786675  3.356393e+00
# AAAGTAGGTCGTGGCT.1 -1.304656e-02  -6.328854195   9.069500967  5.695477e+00
# AAAGTAGGTCTGATCA.1 -9.438662e-01  18.449011158   9.308467594 -3.600749e+00
# AAAGTAGGTGAGCGAT.1 -6.001954e+00  -4.666143894   0.230762806  1.334457e+00
# AAAGTAGGTGGACGAT.1  6.629924e+00   5.917657296  -6.728340092 -5.379873e+00
# AAAGTAGGTTACGACT.1 -2.060919e+00  -3.536230165   6.398960743 -4.419406e+00
# AAAGTAGTCAACACAC.1  2.480052e+01 -15.769094210 -20.457481769  1.567912e+00
# AAAGTAGTCCACTGGG.1 -1.136192e+01 -10.512155048  11.530091649  3.284120e+00
# AAAGTAGTCGCTGATA.1  8.710641e+00 -14.589447257 -22.758033566  4.619192e+00
# AAAGTAGTCTCGATGA.1 -1.529233e+00  -4.916385635  11.559241615 -4.994804e+00
# AAATGCCAGATGCGAC.1  7.422943e+00 -15.772007284 -14.085005313  4.784107e+00
# AAATGCCAGGGATCTG.1 -3.336643e+01  -2.511112827  -4.749423609 -9.257654e+00
# AAATGCCAGTACGTAA.1 -4.883210e+00   0.070490954  -1.005491378 -4.871623e+00
# AAATGCCAGTCCCACG.1  1.062662e+01   0.445499882 -18.548453055  3.599618e+00
# AAATGCCAGTTGCAGG.1  1.661932e-01  16.807206112  -6.467602859 -4.239976e+00
# AAATGCCCAGTGGGAT.1  2.303540e+01   4.654736296   1.240105725 -3.902003e+00
# AAATGCCGTAAGGATT.1  1.092360e+01 -17.682971156  -0.388163462  1.066784e+01
# AAATGCCGTCCAGTTA.1 -6.986372e+00 -10.981539422   2.390651292 -2.088303e+00
# AAATGCCGTCGTTGTA.1  5.966674e+00  -1.337686130   0.038434726 -6.457656e+00
# AAATGCCGTTACTGAC.1 -1.735964e+00  18.622538334   9.274771616 -6.535953e+00
# AAATGCCGTTCAGACT.1 -1.034592e+00   7.700048843 -21.029401805  6.304403e+00
# AAATGCCGTTCTGAAC.1 -1.102786e+01  -9.369910090   6.244516511 -7.372756e+00
# AAATGCCTCACGATGT.1 -1.779506e+00 -16.477208269   3.201831619 -5.002070e+00
# AAATGCCTCCAACCAA.1 -1.694964e+00  -0.427964703 -17.003132929  5.590529e+00
# AAATGCCTCCAATGGT.1  8.372283e+00  15.207566688  -7.357534214 -9.627997e+00
# AAATGCCTCGGTCCGA.1 -6.445871e+00 -12.909961090   8.383122603 -1.911399e+00
# AAATGCCTCGTCACGG.1  1.114608e+01 -14.648434460 -16.309393697  7.546254e+00
# AAATGCCTCTAACCGA.1  1.461867e+01  12.162283986   5.880181685  3.565886e+00
# AAATGCCTCTAACTTC.1 -1.903810e+00  -5.540897668   1.430832663 -5.542980e+00
# AAATGCCTCTCCAACC.1  3.456952e+00  -1.272943995   7.051107893 -8.499527e+00
# AACACGTAGGGTGTGT.1  7.353602e+00 -12.274298384   3.139299998  3.269274e+00
# AACACGTAGTCGCCGT.1 -4.229668e+00  -7.937948628   3.237996228  1.339878e+00
# AACACGTAGTGGAGAA.1 -2.538775e+01 -11.885388173  -5.929873459  8.492934e+00
# AACACGTCACAAGACG.1 -2.310691e+01  -7.981559581   2.888073899  1.113686e+01
# AACACGTCAGTAGAGC.1  4.824915e-01  -1.395550637  -1.023836742 -5.787875e+00
# AACACGTTCCATGAAC.1  3.518839e+00  10.783518386   3.094606219  1.131976e+00
# AACACGTTCGTTACGA.1  4.286291e+00  12.151860139  15.043692837  8.356864e+00
# AACACGTTCTAACTGG.1  3.014197e+01 -14.854711420   4.410837018 -4.909748e+00
# AACCATGAGGAGTAGA.1 -4.782807e+00  10.001804587  -8.348731138 -1.100601e+01
# AACCATGAGGTGTTAA.1 -2.076578e+01   8.064232609  -4.263874388 -8.359353e+00
# AACCATGAGTGAAGAG.1  5.989237e+00 -12.021951847 -20.135773367  1.018969e+01
# AACCATGCACGAGAGT.1  2.799903e+00  -4.690246983   7.304806573 -5.737511e+00
# AACCATGCATCAGTAC.1  6.127990e+00 -17.285845734  -9.059810213  4.699785e+00
# AACCATGGTACCTACA.1  5.020678e+00  -5.902874836  -1.893707058  8.098897e+00
# AACCATGGTATAGGTA.1  9.421231e+00  -1.893356663  -4.723624236  2.305458e+00
# AACCATGGTCAACTGT.1  1.571498e+01  -7.655382641   8.258419722 -9.230224e+00
# AACCATGGTCCGTGAC.1 -2.102474e+01  -7.193287193  -7.703967279  3.801685e+00
# AACCATGGTCGGATCC.1  2.973184e+01 -12.695830450  -1.932332325  9.734271e+00
# AACCATGGTGTTGGGA.1 -4.989482e+00 -13.184059413   5.592876182  3.998123e+00
# AACCATGTCAAACAAG.1 -1.524713e+01  -4.184002405   2.789801817 -4.883818e+00
# AACCGCGAGAAGAAGC.1  3.159187e+01   0.083837012  -6.399478880  8.016976e+00
# AACCGCGAGGACCACA.1 -1.111796e+01  -3.614559995  10.252874954 -1.217471e+00
# AACCGCGAGGGATCTG.1  1.529152e+00  16.639586170  25.136763237  2.138006e+01
# AACCGCGCAACGCACC.1  1.156542e+01   5.389841787  -5.561341742  2.621656e+01
# AACCGCGCAAGGACTG.1 -9.311834e+00  24.910337353  -1.712818314 -5.001510e+00
# AACCGCGCAGACGCTC.1  9.434645e+00   8.317348039   0.574706672 -3.266923e+00
# AACCGCGCATAAAGGT.1 -1.732591e+01   9.713509770   0.688736722  5.590456e+00
# AACCGCGCATGTAGTC.1  6.332624e+00   6.778379563   7.171210695 -2.336594e-01
# AACCGCGGTAGCCTCG.1  2.145481e-02  17.126910019   5.116949770 -7.097236e+00
# AACCGCGGTATTCGTG.1 -2.740456e+01   2.966074307 -11.020639506 -6.490412e+00
# AACCGCGGTGAGGCTA.1 -2.611091e+00 -11.112071623  -4.105732559 -6.727973e+00
# AACCGCGGTTACCAGT.1  1.046252e+01  11.039408032   2.397009179 -1.026267e+00
# AACCGCGGTTCCCTTG.1  1.009170e+01  -2.709769782   1.072656189  5.546057e+00
# AACCGCGTCACCAGGC.1 -1.821037e+01   7.210016838   5.712364773 -7.553422e+00
# AACCGCGTCGGATGGA.1  5.023422e+00  -7.192033438  -8.717264532 -7.068750e+00
# AACCGCGTCGGTCTAA.1  2.353296e+01  14.703631252   7.303975237 -3.755012e+00
# AACGTTGAGCCACTAT.1  4.072058e+00  14.460061181  13.160436674 -3.238781e+00
# AACGTTGAGCTACCGC.1 -8.627282e+00  21.339145197   8.258953987  4.655823e-01
# AACGTTGCAATCGAAA.1  1.355450e+01   2.819321155   3.395259030  5.267243e+00
# AACGTTGCACCAACCG.1 -9.699817e+00  -8.037424387   0.310381889  5.012186e+00
# AACGTTGCATCGGTTA.1  2.427813e+01  11.876031372  -3.283159639  5.369550e+00
# AACGTTGCATGCCCGA.1  4.298955e+00   5.745266358  -8.253852860  1.553106e+01
# AACGTTGGTACTCTCC.1  8.597677e+00   9.281325119  -5.752282125  8.426062e+00
# AACGTTGGTACTTGAC.1 -8.554198e+00  -0.204172871  13.121988373 -3.308048e+00
# AACGTTGGTGCACGAA.1  7.189864e+00  -4.396266018  -0.175897681 -4.332974e+00
# AACGTTGGTTGGTAAA.1  6.033989e+00  -8.403439908   6.228183581 -2.282241e+00
# AACGTTGGTTTGGGCC.1  1.483311e+00  -8.249724511 -11.588958103 -1.100171e+01
# AACGTTGTCGAACTGT.1  1.918798e+01   2.389676968   0.032578026 -8.790252e+00
# AACGTTGTCGGGAGTA.1  1.193842e+01   4.803524664  -5.665344122 -7.736272e+00
# AACGTTGTCTGGTGTA.1  8.012884e+00  -9.847159296  -1.108177038  9.193014e+00
# AACTCAGAGATTACCC.1  1.599904e+01  -9.048836799   0.806301418  5.748970e+00
# AACTCAGAGTCTCCTC.1 -2.760348e+00 -15.041674238   4.648506892 -2.386702e+00
# AACTCAGCAGAAGCAC.1 -4.761126e+00 -14.083039245  -1.627002133 -1.557740e+00
# AACTCAGCAGCCTTTC.1  9.317099e+00   4.901402583  -9.991932865 -1.236562e+00
# AACTCAGGTCAACATC.1  1.515854e+00  12.404180015  -4.007836438  1.800110e+00
# AACTCAGGTCTAGAGG.1  3.662196e+00  -3.745132115  -3.743860347 -2.093778e+00
# AACTCAGGTGCGCTTG.1  1.927293e+01   8.726410891  10.074258549  1.499777e+00
# AACTCAGGTGCTGTAT.1 -1.274727e+01  19.984843088  -5.077746963 -7.405697e+00
# AACTCAGGTTAAGAAC.1 -7.421795e+00  -8.933688545   7.726930744  3.142880e-01
# AACTCAGGTTGTACAC.1 -2.181364e+01  -1.184718561   4.438211057  1.236161e+01
# AACTCAGGTTTGCATG.1 -1.492094e+01  10.966673314  -3.462289464 -9.789335e+00
# AACTCAGTCAGGCGAA.1 -2.238114e+01  -3.800789768  -6.228253862 -9.726026e+00
# AACTCAGTCGCAAACT.1  1.628895e+01 -14.490945677  -6.079639895  4.959462e+00
# AACTCAGTCTGAGTGT.1  7.391519e+00  14.602309200   4.304229961 -4.259361e+00
# AACTCAGTCTTTAGTC.1 -2.101769e+01   1.062032558  -2.492243986 -7.106720e+00
# AACTCCCAGCCGGTAA.1 -2.792346e+01  12.951802792  -0.809904364 -8.693116e+00
# AACTCCCAGGGCTCTC.1 -2.814560e+01  21.849724040 -16.079836236 -8.226572e+00
# AACTCCCAGTGGGCTA.1 -7.616970e+00  -0.726350108   0.272888940  3.901511e+00
# AACTCCCCAAGCGTAG.1 -4.100650e+01   9.057094293 -12.806979005 -1.918442e+00
# AACTCCCCACAGGAGT.1 -2.099939e+01   1.895412929   1.445832475 -4.545811e-01
# AACTCCCCACGACGAA.1  1.005687e+01  -7.807787191  13.149089297 -4.209258e+00
# AACTCCCCACTGTCGG.1  7.078493e+00  -8.902535052  -4.475128890 -1.313138e+01
# AACTCCCCAGGGAGAG.1  1.271405e+01   3.034268718 -15.873242716  2.536129e+00
# AACTCCCCATCCTAGA.1 -1.767686e+01 -11.220131019   2.762297025  1.522344e+01
# AACTCCCCATTCACTT.1  2.347418e+01  -0.832331684   6.656889706 -1.277427e+01
# AACTCCCCATTCTCAT.1  1.028130e+01  10.059198960   0.013804273  3.662496e+00
# AACTCCCGTAGAGGAA.1 -1.370895e+01  -3.964533366   2.642693463 -1.054628e+01
# AACTCCCGTAGGCTGA.1 -3.381096e+01  21.200013594  -5.690166610 -2.729707e+00
# AACTCCCGTATATCCG.1  1.252940e+01 -17.689218680 -11.493787409  1.229700e+01
# AACTCCCGTCCCTACT.1 -1.405047e+00  -6.360720810   0.875265841 -1.293877e+01
# AACTCCCGTGTGGTTT.1  1.227986e+01   6.664854536 -13.034626475  1.650653e+01
# AACTCCCTCTCTGAGA.1 -2.055045e+01  -2.047558558   8.169611440  9.750787e+00
# AACTCCCTCTGATACG.1 -2.447367e+01  -8.834055032   1.437191056  1.239985e+01
# AACTCCCTCTGGCGTG.1 -1.011302e+00   1.154059599   2.997414283 -5.047824e+00
# AACTCCCTCTGTCAAG.1 -1.067563e+01  -9.773012619   4.017459545  1.256074e+00
# AACTCTTAGAGACTTA.1 -3.641903e+00  -9.958781587   4.457115836 -3.455482e+00
# AACTCTTAGCGTAGTG.1  1.503770e+01  -7.088804886  -2.434778879 -1.426531e+01
# AACTCTTAGCGTTGCC.1 -3.177845e+00   1.174114719   5.045918646 -1.352387e+01
# AACTCTTAGTCGATAA.1 -1.659595e+01  -2.750083421   1.228400263  1.163954e+00
# AACTCTTCAATTCCTT.1  3.487497e+00   1.218369341  -8.738884777  1.962288e+00
# AACTCTTCAGCGATCC.1 -6.131666e+00  -9.729745280  -9.791350109 -7.988037e+00
# AACTCTTCAGCTGTAT.1 -5.164077e+00 -15.459498078   4.729818708  1.486388e+01
# AACTCTTCAGGCTCAC.1 -5.407953e+00  12.093022691   2.966244916 -1.369385e+01
# AACTCTTGTAAACACA.1  3.870394e+00  -0.832842914  -1.655925540 -1.497419e+00
# AACTCTTTCAACACCA.1 -2.976941e+01  30.913170245  -4.511769742  1.226309e+00
# AACTCTTTCGGAGGTA.1  6.316916e-01  -5.425865113   7.183988966 -8.943428e+00
# AACTCTTTCTAGCACA.1 -1.534833e+01  -7.506391582  -8.274263641 -7.991278e+00
# AACTGGTAGAAACCGC.1 -6.779781e-01  -3.269432741   0.215557384 -7.707605e+00
# AACTGGTAGAAACCTA.1  4.097136e+00   4.282603253  10.638539573  5.983320e-01
# AACTGGTAGAAACGAG.1 -1.124335e+01  -2.369109197  -4.217064703  7.138156e+00
# AACTGGTAGCCAGGAT.1  7.778452e+00   7.832191034   4.757882601 -2.982345e+00
# AACTGGTAGCGTAATA.1  2.506515e+00 -16.224903832  14.257340642 -2.663447e+00
# AACTGGTAGGGTTTCT.1 -9.437314e+00  -1.440683671   2.976028588  1.544931e+00
# AACTGGTGTCGCGAAA.1  1.468002e+01  -9.211348243  -1.846498136 -5.235140e+00
# AACTGGTGTGCACCAC.1 -2.312740e+01   8.813790864 -14.011903942  3.828456e+00
# AACTGGTGTTAAAGTG.1  1.082097e+01  -5.508215785  -0.075347117 -8.329261e-01
# AACTGGTTCAGTGTTG.1 -2.148424e+00  -6.228033071   4.737697458  3.480796e+00
# AACTGGTTCAGTTAGC.1  1.333896e+00 -11.690408569  -0.278601926 -4.954545e+00
# AACTGGTTCCCTCAGT.1  1.457900e+01   1.656222316  12.896386619 -6.857214e-01
# AACTGGTTCGTTACAG.1 -2.509296e+01  -7.431303027  -2.254661992  1.967107e+00
# AACTGGTTCTGGCGTG.1 -3.554466e+00  -6.232779944  -0.391250125 -1.054803e+01
# AACTTTCAGAAGGTTT.1  2.329421e+01   8.540933572  11.743063629  1.007598e+01
# AACTTTCAGTCTCAAC.1  2.020065e+01   2.375567098 -21.288897571  1.468830e+00
# AACTTTCAGTGATCGG.1  1.983242e+01   9.244361821  12.512732134 -1.441750e+00
# AACTTTCAGTTTGCGT.1 -1.165189e+01  -0.309332605  11.760406485 -9.121626e+00
# AACTTTCCACGGATAG.1 -6.726729e-01   5.587654511 -11.020603318 -7.490979e+00
# AACTTTCCAGGTGGAT.1 -1.345841e+01  13.282531185  -3.879575226 -8.201650e+00
# AACTTTCCATGCATGT.1  7.462799e+00   6.860611073  -7.181386319 -4.720417e+00
# AACTTTCGTATCGCAT.1  1.472470e+01   9.251455370  14.086705239  1.430650e-01
# AACTTTCGTGACGCCT.1  8.731494e+00  14.874509212   4.435994362 -5.489179e+00
# AACTTTCTCATTATCC.1  6.012382e+00  15.280555461  10.661901817  2.762851e+00
# AACTTTCTCCTTGACC.1 -4.645301e+00   2.473352335  -8.516134954 -3.869662e+00
# AAGACCTAGAATTGTG.1  1.199219e+01   9.702714468   8.587460921  2.502095e+00
# AAGACCTAGTAGGCCA.1 -1.910441e+01  10.060955967 -14.192319848  8.677911e-01
# AAGACCTCAACTGGCC.1 -2.952712e+00  -6.219674394   1.564721404 -4.129699e+00
# AAGACCTCAAGACACG.1 -6.020515e-01  -7.142507666   3.419555446  7.352696e+00
# AAGACCTCACCAGATT.1 -1.219205e+01  -0.607235319  -9.703567090 -8.674463e+00
# AAGACCTCACGAGGTA.1 -9.658006e+00   1.285580758   1.670721217  7.593113e-01
# AAGACCTCAGCCTATA.1 -2.530703e+01  23.993757193   2.280777522  2.721346e+01
# AAGACCTTCCATGAAC.1 -4.061508e+01  -5.001805847  -8.511338278  5.477313e-01
# AAGACCTTCCGAGCCA.1  5.522835e+00 -12.667803763   4.259657843  3.070564e+00
# AAGACCTTCGATAGAA.1 -2.084162e+00  -6.678143109   3.853019953 -6.068969e+00
# AAGACCTTCGCCAAAT.1  3.446522e+00  20.159853217   3.968962855  1.405985e+00
# AAGACCTTCTACCTGC.1 -1.721019e+01  -2.416057502  -3.511829630 -5.301712e+00
# AAGACCTTCTCAAACG.1  9.248902e+00  15.047669514   8.095485155 -1.050915e+00
# AAGACCTTCTGCTGTC.1  2.080334e+01  -9.107514103   2.638981559 -9.589696e+00
# AAGCCGCAGAACAACT.1  2.465364e+01  -3.885223865   2.868958294 -5.427856e+00
# AAGCCGCAGAGAGCTC.1  1.512671e+01  13.838908934  13.874497880 -2.643340e+00
# AAGCCGCAGAGGACGG.1 -7.115992e+00   6.846537749 -10.139647660 -2.266420e+00
# AAGCCGCAGATCGATA.1 -1.410995e+01  -8.676638821  -7.494997293 -5.562252e+00
# AAGCCGCAGGCGCTCT.1 -1.157300e+01  -4.721568895   5.333545041 -4.435745e+00
# AAGCCGCAGGTGCAAC.1 -2.510659e+01   0.311820700   6.471465747 -4.708641e+00
# AAGCCGCCATCACGTA.1  1.547342e+01  13.091210372  12.094164701  8.406306e-01
# AAGCCGCGTAAGAGAG.1  1.826165e+00  -8.968098673  13.724033305  5.454083e-01
# AAGCCGCGTCAAACTC.1 -2.136196e+01  -6.219393213   7.184538653 -4.894328e-01
# AAGCCGCGTCTAAAGA.1  5.075820e+00  -5.797673573  -5.278047340 -3.068925e+00
# AAGCCGCGTGGGTATG.1 -1.309942e+01  -8.087693445   2.543726795 -9.916485e+00
# AAGCCGCGTTACCAGT.1 -1.134174e+01  17.272138391  -0.097407208 -1.722162e+01
# AAGCCGCGTTCAGCGC.1 -4.642845e+00 -15.619092067  -0.020098588 -1.948348e+00
# AAGCCGCTCCCTAACC.1 -8.483731e+00   1.268549515   1.160939019 -4.837265e+00
# AAGCCGCTCTCCCTGA.1  1.202911e+01   6.543933854  12.398776817  5.983064e+00
# AAGGAGCAGCAGCGTA.1  2.273854e-01 -13.109005376   5.125714604  1.376778e+01
# AAGGAGCAGTAGTGCG.1  1.366382e+01  13.565213466  11.406545613 -4.399435e+00
# AAGGAGCCAACTGCGC.1  1.564517e+01   5.051611790  -3.700008928 -1.845846e+00
# AAGGAGCCAAGTCATC.1 -1.593977e+01  -8.561033431   0.074284304 -3.798686e+00
# AAGGAGCCAGCCTATA.1  2.559827e+01   7.756235840   6.453182887 -5.190842e+00
# AAGGAGCCAGGCGATA.1 -1.939733e+01   9.946521612  -4.905578823 -5.558417e+00
# AAGGAGCGTCAGCTAT.1 -1.928269e+00  12.562703593  -5.672397313 -4.232930e+00
# AAGGAGCGTGTTAAGA.1 -5.833371e+00  -8.281395365  -0.274245698 -8.719159e+00
# AAGGAGCTCCACGACG.1 -1.485034e+01  -1.765485547   3.660250194  5.529736e-01
# AAGGAGCTCCCAGGTG.1  6.158005e+00  -7.610716992 -13.849205101 -2.311715e+00
# AAGGAGCTCGAACGGA.1 -1.995172e+01   3.028683347  -1.472723899 -3.728791e+00
# AAGGCAGAGACTAGAT.1 -1.443134e+00  14.935269348  -2.164262958  5.264269e+00
# AAGGCAGAGCCGCCTA.1 -5.151367e+00 -15.295263145 -17.366359840  9.965599e+00
# AAGGCAGAGGGTCTCC.1 -2.119706e+01 -13.130986110   4.393205380 -2.842810e+00
# AAGGCAGAGGTCATCT.1 -8.661641e+00  -6.450730343   1.399041491 -3.588820e+00
# AAGGCAGCAAGTTGTC.1  2.164159e+00  17.772099961   4.039938383  8.870791e+00
# AAGGCAGCAGTAAGAT.1 -1.814466e+01  -1.165612448  -1.658799686 -9.049234e+00
# AAGGCAGGTAGTGAAT.1 -9.499673e+00  -2.765134984  -0.771592669 -3.407262e+00
# AAGGCAGGTCGCCATG.1 -2.155024e+01 -11.073377874   1.742473960 -5.521651e+00
# AAGGCAGGTCTCGTTC.1 -2.821352e+01  -6.865869685   7.261909073 -2.476576e+00
# AAGGCAGGTTCAGCGC.1  1.032722e+01  -7.072548933  -1.956621634 -6.099265e+00
# AAGGCAGTCAACGGCC.1  2.229159e+01   5.626251871   4.357048683 -6.455323e+00
# AAGGCAGTCACCGTAA.1 -1.060792e+01  -9.500049205   9.225804408  3.234292e+00
# AAGGCAGTCCGGGTGT.1  2.577124e+00  -4.075890772   2.554587503 -1.152632e+01
# AAGGTTCAGATCACGG.1  7.006657e+00   2.657991447  -3.238179398 -6.652020e+00
# AAGGTTCAGTACATGA.1 -1.107589e+01 -12.984356584  -1.967347771  1.377485e+00
# AAGGTTCAGTCCCACG.1 -3.457474e+01  24.500741471 -10.424541514  4.753782e-01
# AAGGTTCCAAGCTGTT.1 -1.541543e+01  -7.513317608  -4.350070244 -1.015565e+01
# AAGGTTCCAAGGACTG.1 -2.760364e+00  -0.723137891  -0.018443835 -1.185861e+01
# AAGGTTCCACATGACT.1 -2.226903e+01  -6.247768284   0.384661698 -1.549502e+01
# AAGGTTCCACCAGGCT.1  5.201015e+00 -13.026229971   7.514976237 -2.831540e-01
# AAGGTTCTCGATCCCT.1 -2.441593e+01   2.788191214  -9.269730174 -8.225291e+00
# AAGTCTGAGAAGATTC.1 -1.513873e+01  -3.396683676  -0.167367971  1.432160e+00
# AAGTCTGAGATGAGAG.1  2.760156e+00  -7.535022415 -20.363341276  3.366092e+00
# AAGTCTGAGGCCCGTT.1 -3.122134e+01  -6.814489564  -6.174488436 -1.210145e+01
# AAGTCTGAGGCTACGA.1  3.321527e+00 -18.414359083   8.391383796 -3.499314e+00
# AAGTCTGAGTCGATAA.1 -3.884421e+01  -3.070352069 -10.949482049  2.225220e+00
# AAGTCTGAGTGAAGAG.1 -1.256757e+01  -1.449367675   5.123202559 -2.535894e+00
# AAGTCTGCAATAGCAA.1  5.182061e+00  -8.480401547  -1.201998363  4.652610e+00
# AAGTCTGCAATGGACG.1 -2.056982e+01  18.006866293   7.883974329 -3.845803e+00
# AAGTCTGCACCAACCG.1 -2.949731e-01  11.899675249  -1.444413069 -1.396687e+01
# AAGTCTGCACGGCCAT.1 -1.385219e+01  -4.575547869  11.201840977  5.326363e-01
# AAGTCTGCAGGTTTCA.1 -3.144852e+01  -9.286739676   3.359039490  9.362476e+00
# AAGTCTGCATCTCCCA.1  2.133596e+01  12.182487565  20.100313411  6.430133e+00
# AAGTCTGGTAATCGTC.1 -8.616489e+00   1.200274929   1.516890012 -2.856824e+00
# AAGTCTGGTACCGGCT.1 -7.947673e+00  -0.049757513  -1.403297259  3.875729e+00
# AAGTCTGGTCCCGACA.1 -1.952348e+01  -0.458626809  -0.914191777 -3.395714e+00
# AAGTCTGGTCTAACGT.1 -2.308728e+00  11.091814814  -1.451497297  1.800958e+01
# AAGTCTGGTGTAACGG.1 -1.814265e+00  -9.105500170  16.053727147  6.368895e+00
# AAGTCTGGTTGGTTTG.1  1.264045e+01 -11.823689946 -11.195216287 -4.330580e+00
# AAGTCTGGTTTCGCTC.1 -1.908986e+00  19.644420276  -0.553785759  4.150215e+00
# AAGTCTGTCATCGATG.1  4.120562e+00  -9.187523360   3.676071984 -4.764400e+00
# AAGTCTGTCTGAGGGA.1 -2.402122e+01  17.498423010   0.337359567 -6.910094e+00
# AAGTCTGTCTTGTCAT.1  1.573312e+00  -6.720815644  14.505878338  5.315991e+00
# AATCCAGAGAGCCCAA.1  7.064152e+00   5.014319045   4.591321455 -1.851349e+00
# AATCCAGAGCCCGAAA.1 -6.609555e+00  -0.163654436   0.126674628 -1.079306e+00
# AATCCAGAGGGCACTA.1  1.119731e+01  -7.488702200 -11.306476271  3.736583e+00
# AATCCAGCAGCTGTTA.1  6.052976e+00  13.707783208  11.132423737 -6.923976e+00
# AATCCAGCAGGATCGA.1 -6.308511e+00  -2.454299542   3.873177760 -7.748663e+00
# AATCCAGCATCAGTAC.1  1.276381e+01 -11.270916892 -19.972226183  5.462040e+00
# AATCCAGCATGTAGTC.1  1.278962e+01   2.017431578  -2.088384222 -8.913765e-01
# AATCCAGGTACGAAAT.1  6.494416e+00  -8.179874629   2.919770764 -4.131463e+00
# AATCCAGGTACTCGCG.1 -1.785394e+01   1.640825728 -12.207016398  1.540522e+01
# AATCCAGGTATTCTCT.1 -8.893713e+00  -8.022754467 -11.246971004  2.583304e+01
# AATCCAGGTGTGAAAT.1 -6.568114e+00  -4.798025085  -7.692900322 -6.701884e+00
# AATCCAGTCACGCATA.1  6.418966e+00  -8.576636877  -4.061561815 -3.438044e+00
# AATCCAGTCATGCTCC.1  8.125129e+00   3.717682356 -12.750755867 -1.591096e+00
# AATCGGTAGACTAAGT.1 -8.163947e+00  -2.554390180   7.138208183 -1.813740e+01
# AATCGGTAGACTCGGA.1  4.810652e+00  18.317841787 -11.628192126 -5.407754e+00
# AATCGGTAGATAGGAG.1  6.309773e+00   8.214758186 -12.493106672 -2.996749e+00
# AATCGGTAGTCCGTAT.1 -5.161524e+00  13.671252021  -2.401917368 -7.754859e+00
# AATCGGTCAAACGCGA.1 -1.155618e+01  -5.138348378   7.754453216  1.786262e+01
# AATCGGTCAGCCAGAA.1 -4.761886e+00  11.524085720   2.711858439 -9.680384e+00
# AATCGGTCATAAAGGT.1  2.685486e+01  -2.457290066  -3.612495666  4.287882e+00
# AATCGGTGTACTTAGC.1  4.251522e+00  -9.263861600   3.873457397 -9.961375e+00
# AATCGGTGTCCTGCTT.1  1.043713e+01  15.685461330  10.651379485 -7.683324e+00
# AATCGGTGTGACTCAT.1 -1.282540e+01  -4.324053740   1.871117726  4.718651e+00
# AATCGGTGTTCACCTC.1  1.075042e+01  15.977701532   1.288378926  1.072610e+01
# AATCGGTTCAGCTTAG.1 -1.603165e+01  -2.559937428   5.062922019 -4.367555e+00
# AATCGGTTCATAGCAC.1 -3.773535e+00  -3.714238624   8.414898581 -2.748020e+00
# AATCGGTTCTACTATC.1 -1.676604e+01   8.957169381  -9.821083252 -8.493247e-01
# ACACCAAAGACAATAC.1  9.356622e+00 -15.292085942  -4.562953532  1.536898e+01
# ACACCAAAGACCCACC.1 -7.793658e+00  -8.949619444  -6.256546680 -5.756791e+00
# ACACCAAAGACCGGAT.1 -1.342850e+01 -12.052966046  -0.803323495 -4.330493e+00
# ACACCAAAGCGTTTAC.1 -6.119392e+00   2.353288431   6.944951415 -5.986069e+00
# ACACCAAAGGGTTCCC.1 -1.247859e+01 -11.407309130   2.160003824  3.827284e+00
# ACACCAAAGTACTTGC.1  4.287755e+00  -0.956732477   7.388229463 -1.010572e+01
# ACACCAAAGTGTGGCA.1  2.382686e-01   2.191671838   9.535465233  1.938860e+00
# ACACCAACAATCGGTT.1 -1.272938e+01 -15.955114233  16.318137849 -3.643611e+00
# ACACCAACACGTCAGC.1 -2.198113e+01  -6.500710201   0.572101733  1.495543e+00
# ACACCAACACTCTGTC.1  1.460232e+01 -21.069488664 -11.330488260  9.808243e+00
# ACACCAAGTATAAACG.1 -9.145426e+00  -1.412074038  14.650054897  6.927886e+00
# ACACCAAGTGTATGGG.1 -4.380217e-03  11.116566751 -12.571953257 -1.838063e-01
# ACACCAAGTGTCCTCT.1 -1.854713e+01  -9.771540884  -3.669834689 -4.153885e+00
# ACACCAAGTTTAGGAA.1  2.122333e+01 -12.894580556 -19.443502118 -2.855223e-01
# ACACCAATCGGCGGTT.1 -2.632694e+01  -5.830223362   4.143900410 -5.708721e+00
# ACACCAATCTACCAGA.1 -1.465284e+01  -8.971042933  -4.054906697 -1.762663e+00
# ACACCAATCTGTCCGT.1  2.066683e+01  -2.925075028  12.375083067  7.463892e-01
# ACACCAATCTTCGGTC.1 -3.083574e+01   0.507396752   3.123799089 -7.278484e+00
# ACACCCTAGAGCTGGT.1  1.371722e+01  14.779897349  11.193560102 -8.641234e+00
# ACACCCTAGAGTGACC.1 -1.115787e+01   1.517329408  14.473711319 -4.928657e+00
# ACACCCTAGCCACCTG.1 -2.265108e+01  -1.458515210  16.842183389  1.312732e+00
# ACACCCTAGGCATGGT.1 -7.440433e+00  -8.189928717  -5.872931931 -2.498361e+00
# ACACCCTAGGGCTCTC.1  4.845206e+00  -6.620134821  -9.954227902  3.244885e+00
# ACACCCTCACTCTGTC.1  1.495421e+01  12.893708746  13.158504184 -6.414679e+00
# ACACCCTCAGTCACTA.1 -2.467751e+01   1.963557646 -10.869374218  8.578488e+00
# ACACCCTGTCTTCAAG.1 -6.503096e+00  -7.911827808  -3.138630048 -9.521422e+00
# ACACCCTGTGCTCTTC.1 -1.975312e+00  10.994038445 -17.728712833 -3.963337e+00
# ACACCCTGTTCGCTAA.1  1.264973e+01  12.380300257  13.060432778  5.183263e+00
# ACACCCTGTTGTTTGG.1  6.006782e+00  -6.900815234   6.277447975 -1.327271e+01
# ACACCCTTCGGAGCAA.1  2.361137e+00  18.472152177  -0.820693669  3.474234e+00
# ACACCCTTCTACTATC.1  3.334555e+00  14.349195685   3.577102211  4.783048e+00
# ACACCGGAGAACAATC.1 -5.550396e-01  -2.220514773  -3.249683049 -1.235876e+01
# ACACCGGAGAACTCGG.1  5.401222e+00  14.669135783  -9.167031832  3.188767e+00
# ACACCGGAGACTACAA.1  2.918259e+00  -6.798889048   6.696151179  8.517033e+00
# ACACCGGAGGCGACAT.1  6.005500e+00  16.081120257   3.822185369  4.739308e-01
# ACACCGGAGTGTTTGC.1 -1.090690e+01  -1.808499870   7.210283124  8.531787e+00
# ACACCGGCAAGCGTAG.1  7.165302e+00   4.192713285  -3.521606491  1.694520e+01
# ACACCGGGTTATCACG.1 -8.929252e+00 -15.228128508  -9.590525366  6.233687e+00
# ACACCGGGTTCCACTC.1 -1.040976e+01  14.347074840  -1.153066913 -1.420500e+01
# ACACCGGTCAGCACAT.1 -2.019295e+01   0.091449898   1.731864348  2.120101e+00
# ACACCGGTCAGGCCCA.1 -2.855489e+00 -14.759982347   1.846914298 -8.795226e+00
# ACACCGGTCCGCTGTT.1 -1.572965e+01  -2.496683333   0.175218127  3.537740e+01
# ACACCGGTCGCTAGCG.1  8.042555e+00 -11.434522938   4.989147421  4.560341e+00
# ACACCGGTCTTCGAGA.1  9.809680e+00 -16.857645542   7.041018368 -9.206209e-02
# ACACTGAAGCCCTAAT.1  2.367778e+00  14.588625225 -15.263765740  1.352748e+01
# ACACTGAAGTACGCCC.1 -5.760878e+00  -1.215218338   1.975096940 -1.022799e+01
# ACACTGAAGTCCTCCT.1 -1.551337e+00  19.689283862   6.493654085  9.322203e+00
# ACACTGAAGTGACTCT.1 -1.243593e+01  -3.014609576   3.917753816 -8.930637e+00
# ACACTGAAGTGGTAGC.1 -2.033521e+01   2.045492816   2.566241950 -9.211771e+00
# ACACTGAAGTTGAGTA.1 -1.070798e+01  16.607742141  -1.863804144 -1.149310e+00
# ACACTGAAGTTTGCGT.1  1.457661e+01 -15.035008448 -20.587581532  2.847061e-01
# ACACTGACAACACGCC.1  1.985941e+00  -3.513792933  -1.324298179 -1.376620e+00
# ACACTGACAAGAGTCG.1  4.296129e+00  14.817002497   1.847982393  3.531303e+00
# ACACTGACACGCCAGT.1  3.781427e+00  14.548528375 -15.938391573  6.208532e+00
# ACACTGACAGCGTAAG.1  1.161233e+01 -10.825977832  11.614789170 -1.028528e+01
# ACACTGACAGGACCCT.1  1.814602e+01 -21.617442311   4.389028221 -6.003144e+00
# ACACTGACATCGGGTC.1  8.083018e+00 -13.532900620  18.871049233  7.763316e+00
# ACACTGAGTACGCTGC.1 -1.399397e+01  -2.507438991  -2.147227056 -1.058388e+01
# ACACTGAGTCTTCTCG.1 -6.295820e+00 -18.126641136  11.903080517  3.975614e+00
# ACACTGATCCAGGGCT.1  2.483939e+01   1.504881572  12.094578279 -5.602013e+00
# ACACTGATCGTACGGC.1  5.240795e+00  -6.337721988   0.744977976 -1.466870e+00
# ACAGCCGAGAGTTGGC.1  1.461355e+01  -0.381433340   7.327879201  2.463972e+00
# ACAGCCGAGCAGGTCA.1 -1.013421e+01  -3.331365350  -2.019508048 -1.123978e+01
# ACAGCCGCAAACCTAC.1  6.518905e+00  16.488823434  11.120210843  5.780122e+00
# ACAGCCGCAAGTAATG.1 -1.308576e+01 -10.340475318  10.829857018  1.181381e+01
# ACAGCCGCACAACGTT.1 -8.831682e+00   5.619578283   4.141697467  8.306195e-01
# ACAGCCGCACGTTGGC.1 -2.376515e+01  -1.956308060   6.181046758  8.442829e-01
# ACAGCCGCAGACTCGC.1 -6.020938e+00  -3.990206424   0.817824121 -1.228729e+00
# ACAGCCGCAGCGTAAG.1  4.919090e+00  -9.698480731   2.305497707 -2.100221e+00
# ACAGCCGCAGGTGGAT.1 -2.544317e+01 -12.772387857  -4.325133662  9.732755e+00
# ACAGCCGCATGTAAGA.1 -9.552791e+00  -5.321850927  -3.474903394  1.047322e+01
# ACAGCCGGTTCCGTCT.1 -2.970617e+01  -0.888013068  -4.793461427 -3.102883e+00
# ACAGCCGTCAAGATCC.1  7.534793e+00  12.928626319  -3.761457577  5.595254e+00
# ACAGCCGTCACTTATC.1  2.570232e+01  -7.810340480  10.094774423 -3.769744e+00
# ACAGCCGTCCTCATTA.1 -2.939050e+00  11.762762668 -14.391167228  1.242334e+01
# ACAGCCGTCGTTTAGG.1  1.578259e+01   5.103045939   5.263193041 -4.388980e+00
# ACAGCTAAGGCTACGA.1 -4.879730e+00  -7.061217906 -11.676388372  2.411458e+00
# ACAGCTAAGTGGACGT.1 -1.121433e+01  -3.367723113   0.910928713  4.130932e+00
# ACAGCTACACATGTGT.1 -9.038344e+00  -8.272675112   2.502526317  6.028799e+00
# ACAGCTACACATTTCT.1 -2.130854e+01  -8.341204919   5.266160091 -3.512073e+00
# ACAGCTACACCCAGTG.1  2.972758e+01   2.702788959 -14.554179313 -2.147651e+00
# ACAGCTACAGGTCCAC.1  3.227839e+01   3.503531156   8.362495236 -4.349508e-01
# ACAGCTACATATACCG.1 -6.014137e+00  -4.285467560  14.606056452 -6.997670e+00
# ACAGCTACATCACCCT.1  2.491298e+00   5.802993313  -2.421741203 -2.511674e+00
# ACAGCTAGTCTACCTC.1 -2.547122e+01  -3.331307988   0.684872514  1.525894e+00
# ACAGCTATCTGTCCGT.1  1.133363e+01  10.442531813  -7.873421855 -8.567257e+00
# ACAGCTATCTTAGCCC.1  2.676626e+01 -19.262518633  10.309392264 -3.487988e+00
# ACATACGAGCCGGTAA.1  2.030102e+01 -17.351048512  -4.106953218  1.528625e+01
# ACATACGAGCGGATCA.1  3.406130e+01  -6.318954785   2.337157626  2.437333e+00
# ACATACGCAACGCACC.1 -1.017643e+01   6.881959429  -3.215175248 -1.244057e+01
# ACATACGCAAGCGCTC.1  2.700804e+01   3.958941625  -7.514444519  2.298168e+00
# ACATACGCAAGTCTGT.1  6.851995e+00  12.495389894  -2.254842343 -2.485860e+00
# ACATACGCACAGACAG.1 -5.743263e+00  -4.516980848   1.738345927  5.101256e-01
# ACATACGCATCCGTGG.1 -6.859734e-02  -8.897311112   0.114626944 -1.177369e+01
# ACATACGCATCGGAAG.1 -2.882914e+01  -0.721792836  -4.022649938 -4.111903e+00
# ACATACGCATGAAGTA.1 -2.195200e+00  -5.581009855   5.698329341 -2.139309e+00
# ACATACGCATTAGCCA.1  2.132133e+01 -10.059068870  -3.454234574  3.795537e+00
# ACATACGGTAAGGGAA.1 -1.373991e+00   1.261058634   2.011520883  3.420066e+01
# ACATACGGTCGACTAT.1  2.784441e+01   5.195472253 -13.749756276  3.830836e-01
# ACATACGGTCGCATAT.1  1.678345e+01  -7.675124607  -4.043353278  5.240615e+00
# ACATACGGTGTAACGG.1  1.021733e+01  12.291721132   7.985263867 -3.414298e+00
# ACATACGGTTATCGGT.1  7.547966e+00 -10.092952142  -9.666074766 -1.001836e+01
# ACATACGGTTCCTCCA.1 -2.642211e+00  -5.273552830   4.982876677 -5.465194e+00
# ACATACGGTTGGGACA.1  6.797380e+00 -14.377924499  -5.961231603 -3.414753e+00
# ACATACGTCCCAAGAT.1 -1.641757e+01   0.875753177  -3.090877513 -1.116792e+01
# ACATACGTCCCATTAT.1 -1.932537e+01  -0.926960893  10.398675361  9.040684e+00
# ACATACGTCGGCGCAT.1 -1.555031e+00  22.775857957  -1.850159843 -2.170619e+00
# ACATCAGAGCATGGCA.1  5.668114e-01  -8.378815939  10.662534631  2.869498e+00
# ACATCAGAGGGTTCCC.1 -1.171938e+01  -8.466940050  13.163683423 -2.959820e+00
# ACATCAGCAAGCCCAC.1 -5.764512e+00   9.468097728   4.006388507 -5.891590e+00
# ACATCAGCACGGACAA.1  6.800879e+00  12.927010338   2.812022149 -5.617715e+00
# ACATCAGCACTAGTAC.1 -2.405322e+01  -5.180846744   3.355469845 -9.463664e+00
# ACATCAGCACTTCGAA.1  2.317094e+01 -14.449247892 -11.596247838  2.741201e+00
# ACATCAGCAGGCTCAC.1  2.321668e+01  -7.859843533   8.228546105  2.519567e+00
# ACATCAGCAGGGTATG.1 -9.218021e+00   9.757504444   1.230985866 -1.609133e+01
# ACATCAGCATGCCCGA.1  2.648402e+01   3.974496980  -1.521602773 -5.530866e+00
# ACATCAGCATGTTCCC.1 -7.532104e+00  -5.532684138   5.224063858 -5.221583e+00
# ACATCAGGTATAGGGC.1 -7.834339e+00   0.150506135 -11.107315430 -7.784251e+00
# ACATCAGGTCGAAAGC.1  1.729430e+01   7.431792427  10.060123873  8.165591e+00
# ACATCAGGTTGGAGGT.1  1.658930e+01   4.626497606   9.139407376  6.260871e+00
# ACATCAGTCACTTACT.1  8.081704e+00  -2.078968311   6.245263638 -1.754104e+00
# ACATCAGTCCATGAAC.1  8.749006e+00  -9.592564871  -1.645113414 -5.162195e+00
# ACATCAGTCCATTCTA.1  4.434633e+00  12.642814620  -6.435455569 -8.080225e+00
# ACATCAGTCGCGTTTC.1 -8.652014e+00  17.832965957   5.980998078 -7.425884e+00
# ACATCAGTCGGATGGA.1 -1.792278e+01   9.134589291  -7.536190437 -5.878252e+00
# ACATCAGTCGGCGCTA.1  5.364557e+00  -0.763564677  13.543600431 -2.186497e+00
# ACATCAGTCGTCACGG.1 -4.623545e-02   5.472615916   2.271249732  5.533538e+00
# ACATGGTAGACCTAGG.1  6.865861e-01  -3.369482081   0.366645257  1.583969e+00
# ACATGGTAGACTAAGT.1 -1.358766e+01  -9.326118467   7.458513777 -2.048325e+00
# ACATGGTAGATCCCAT.1  1.018522e+01   5.604419450   3.943312326 -1.622978e+00
# ACATGGTAGCACACAG.1 -2.275582e+01  15.325649754  -3.315115332  2.884399e+00
# ACATGGTAGGAATGGA.1 -5.639835e+00  16.018365029  -8.640397455 -7.331773e-01
# ACATGGTAGTATTGGA.1  1.711068e+01  -6.639028041  -2.517371209 -1.612819e+00
# ACATGGTCAAGAGGCT.1 -7.107919e+00   9.328598610  -3.750437163 -1.241815e+01
# ACATGGTCACGCATCG.1  1.942237e-01 -14.308274274   8.180968074  2.349516e+01
# ACATGGTCAGCCAATT.1  2.075661e+01  -7.012611173  12.634347091 -9.788127e+00
# ACATGGTGTAGGAGTC.1  1.049176e+01  14.458931726  11.997311661 -1.951557e+00
# ACATGGTGTAGGCTGA.1 -1.909643e+01  -8.902280041   4.645840786 -3.357300e+00
# ACATGGTTCACGGTTA.1 -1.237442e+01  -4.097473207   1.967128372  7.654357e+00
# ACCAGTACAATTGCTG.1 -8.702223e+00  -5.938494308   0.767519915 -9.866685e+00
# ACCAGTACACTCTGTC.1 -2.254748e+01  15.947164188  -8.064417725 -2.763703e+00
# ACCAGTACAGATGAGC.1 -7.655736e+00  -1.248676224   3.965297305 -4.115427e-01
# ACCAGTACAGGTGGAT.1 -4.055214e+01 -11.500429631 -10.557492099  8.796142e+00
# ACCAGTACATTCGACA.1  8.304006e+00   0.077303994  -2.890679380  2.267263e+00
# ACCAGTAGTAAGGGAA.1 -2.131990e+01  14.002521683  -2.157666498 -7.031816e+00
# ACCAGTAGTAGCCTCG.1  5.756735e+00  16.662909967   4.590812765 -1.353582e+00
# ACCAGTAGTCCGTGAC.1 -9.805018e+00  -0.511679545 -15.500934429 -6.352524e+00
# ACCAGTAGTCGCGAAA.1  3.927094e-01  -0.399294409   1.025307628 -9.373342e+00
# ACCAGTAGTCGGGTCT.1  6.069478e+00  10.614007810  10.175913050  2.154320e+00
# ACCAGTAGTCGTCTTC.1  6.202213e+00   8.831343870  -8.805483828  1.648356e+00
# ACCCACTAGACAAGCC.1  6.555623e+00  11.456183013  -7.383460846  9.732949e+00
# ACCCACTAGAGCTATA.1  6.447450e+00  16.039142377  14.736750224  3.679238e+00
# ACCCACTAGTAGGTGC.1 -4.341807e+00  -6.959229357   8.339312428  2.988958e+00
# ACCCACTCAAGGACAC.1 -1.128576e+00  -1.435040700  -4.258086579 -6.944292e+00
# ACCCACTCACCTATCC.1  8.720013e+00  11.877971347   0.042867534 -7.322862e+00
# ACCCACTCAGATCGGA.1  3.164888e+01   6.655382233  -2.182963092  3.086891e+00
# ACCCACTGTCCGCTGA.1 -1.726585e+01  -6.332144073  -1.198312888 -2.516866e-01
# ACCCACTGTCGAACAG.1 -2.093342e+01  -0.473183559   8.123273401  6.988750e-01
# ACCCACTGTGCCTTGG.1 -1.012019e+01   0.633699850  -1.047475847 -5.295778e-01
# ACCCACTGTGTGTGCC.1  1.708652e+01   9.986234685  10.048414895  4.306571e+00
# ACCCACTTCAAACCGT.1  4.695118e+00  16.338336783  15.803131096  7.000063e-01
# ACCCACTTCAACACTG.1 -9.177035e+00  -3.560260162   0.134892545 -1.211663e+01
# ACCCACTTCATACGGT.1  2.415328e+01 -14.708020868 -13.118002929  4.432529e+00
# ACCCACTTCCACGTTC.1 -1.505493e+01  -5.937792412   6.877614197 -5.041270e+00
# ACCCACTTCGAGAGCA.1 -2.127516e-01   2.186950224  -4.922271780 -1.109466e+01
# ACCCACTTCTAACGGT.1 -1.169754e+01  -0.969879490  -3.674781040 -6.846176e+00
# ACCCACTTCTAAGCCA.1  5.764907e+00  15.476593506  11.558607700 -8.188849e+00
# ACCGTAAAGAATTCCC.1  9.354502e+00  -4.658338644   4.514174007 -9.989978e-01
# ACCGTAAAGAGCTGGT.1  1.088008e+01  14.682979976   7.727040877  3.861934e+00
# ACCGTAAAGGAGTAGA.1  1.202192e+01   4.501707942   1.222274587  4.204417e+00
# ACCGTAACAGCATACT.1  2.925058e+01  10.836594874   9.731374266  1.363210e+00
# ACCGTAACATGAAGTA.1 -8.982622e+00  -0.050668899   4.987008572 -6.030886e+00
# ACCGTAAGTGGTCCGT.1  1.156240e+01   9.476598693   8.348282763 -1.123209e+01
# ACCGTAATCACATACG.1  1.733588e+01   3.183966072   9.248718877 -2.266705e+00
# ACCGTAATCACATAGC.1 -9.213674e+00  -6.348232460  -9.218083626  1.026285e+00
# ACCGTAATCGCTGATA.1  1.063268e+01  -9.798979940 -12.466478046 -8.635630e+00
# ACCTTTAAGAGCCTAG.1 -8.710324e+00  -8.635351063   5.590650526  1.586005e-01
# ACCTTTAAGCTGAAAT.1 -5.351597e+00   4.440394768   0.513001635 -3.157281e+00
# ACCTTTAAGTCGCCGT.1 -2.307674e+01  -1.084531065  -2.468051999 -4.910199e+00
# ACCTTTACACCGGAAA.1 -1.155471e+01  -5.906715665  12.650481669 -8.171088e+00
# ACCTTTAGTCGCATCG.1 -9.929021e+00  -7.517314254   6.946833502 -5.816780e+00
# ACCTTTAGTGATGTCT.1 -7.797036e+00  -7.257921160   1.938155699 -4.547283e+00
# ACCTTTAGTTGGTTTG.1 -7.736029e+00  -4.735570880   8.447216172 -4.735882e+00
# ACCTTTAGTTTGGGCC.1  4.136206e+00  18.618686172   5.779334639  1.138739e+01
# ACCTTTATCACAGGCC.1 -1.452000e+01 -20.131918463  15.652337650  5.019995e+00
# ACCTTTATCACATGCA.1 -1.218883e+00   4.874599673   0.815751379 -5.470094e+00
# ACCTTTATCCCTCTTT.1  1.987211e+00   4.802710827   1.765205433 -8.751072e+00
# ACCTTTATCTACCTGC.1 -2.414334e+01  15.327755828  -3.465425444 -1.185447e+01
# ACCTTTATCTCCAACC.1 -1.712854e+00  -3.480938676  -3.830901011  2.703798e+00
# ACCTTTATCTGATACG.1  1.097928e+01 -11.723958891  11.692979857  1.801501e+01
# ACCTTTATCTTCATGT.1 -8.804931e+00 -10.245643275  -1.151066051 -3.756352e+00
# ACGAGCCAGAGGGCTT.1  2.328151e+01   6.183680188  14.074409652  1.226962e+01
# ACGAGCCAGCTCCCAG.1 -3.867974e+00  14.792225350  -9.778911471 -1.127585e+01
# ACGAGCCCACTACAGT.1 -1.602484e-01  15.764855043 -17.462297006  1.720235e+00
# ACGAGCCGTGACTACT.1  6.075078e+00  11.295336959   9.213493407  4.257939e+00
# ACGAGCCGTTCCCTTG.1  7.188261e+00  -9.286347108   2.758706338 -4.000499e+00
# ACGAGCCTCAGTTTGG.1  2.887920e+01   9.806115967   1.054122703 -6.122701e+00
# ACGAGCCTCATACGGT.1  7.579266e+00  -4.363247005   5.380559538 -8.290012e+00
# ACGAGCCTCCGCAAGC.1 -7.835191e+00  -3.658197497  -2.490113295 -2.468824e+00
# ACGAGCCTCCTTTCTC.1 -5.629787e+00 -13.810388336  -3.089454081  9.842143e+00
# ACGAGCCTCTGTACGA.1  5.773967e+00  16.196717307  12.093961877 -4.934120e+00
# ACGAGGAAGATCCTGT.1 -7.955475e+00  -5.506280345   2.474378959 -7.333705e+00
# ACGAGGAAGCGCTTAT.1 -1.761471e+01  16.563020148  -6.885520993 -1.212279e+01
# ACGAGGAAGGCTACGA.1 -7.424705e+00   5.368522987   3.416214484  5.238815e+00
# ACGAGGAAGGGCTTCC.1 -1.614528e+01  -5.842718913   0.286678195 -5.545918e+00
# ACGAGGAAGTATCTCG.1 -1.915492e+01  -5.810718181   1.881053043 -1.863572e+00
# ACGAGGACAAGGTTCT.1  1.902197e+01  11.559944509   8.009311274  2.402342e+00
# ACGAGGACAAGTAATG.1 -1.017884e+01  -5.109662878   2.440138211 -7.187832e+00
# ACGAGGACAATGGTCT.1 -9.003720e+00   9.538272184  -4.419594871  1.544705e+00
# ACGAGGACACTCGACG.1  2.490693e+01   2.101918171   9.992410979 -2.025270e+00
# ACGAGGACACTGTTAG.1 -9.365664e-01   4.680401828  -2.169635906  1.173057e+01
# ACGAGGACAGTCGATT.1 -1.143376e+01   6.399274942   0.927328771 -4.261744e+00
# ACGAGGACATACTCTT.1 -7.104045e+00  -6.442210368   0.671340736 -5.529591e+00
# ACGAGGACATATGCTG.1  6.267160e-01   9.809878681 -11.831074648  6.779550e+00
# ACGAGGACATGCCTAA.1  3.276724e+00  10.775242264 -13.278394831 -6.933320e+00
# ACGAGGACATGGGAAC.1 -7.674628e+00  25.266200816   0.794267461 -2.693614e+00
# ACGAGGACATTTCAGG.1 -1.901246e+01  -5.578840023  15.792323245 -1.209795e+01
# ACGAGGAGTACCGTAT.1 -1.228350e+01  12.779095366  -9.164980650 -9.117741e+00
# ACGAGGAGTATCAGTC.1  3.034463e+01   3.117012872   0.428553558  1.059468e+01
# ACGAGGAGTCATCGGC.1 -5.157274e+00  -6.259400970  -0.005566112 -5.509864e+00
# ACGAGGAGTCGTTGTA.1 -2.000610e+01  -7.428491731  -0.799153466 -1.641968e+01
# ACGAGGAGTGCCTTGG.1 -3.256780e+00  -3.569031877   7.362704152 -3.243503e+00
# ACGAGGATCACTCTTA.1 -4.609093e+00  -8.702074981  -4.050054389  3.796906e+00
# ACGAGGATCTCTGCTG.1 -1.084347e+01  17.955036871  -2.987859468 -2.755990e-01
# ACGATACAGCGTAATA.1 -2.139757e+01   1.083744372  -4.248468690 -1.574758e+00
# ACGATACAGGAATTAC.1 -5.045996e+00  -4.058695441 -18.279986328 -3.170194e+00
# ACGATACCAACGATCT.1 -7.314142e+01  25.765697028 -18.717009886  2.717694e+01
# ACGATACCACAACTGT.1  4.575245e+00   4.569390606  11.049600341 -1.244164e+01
# ACGATACGTAAATGTG.1 -1.985961e+01  -9.994400852   4.646584676 -5.588313e+00
# ACGATACGTCACAAGG.1  8.277848e+00   2.889507596 -15.861076262  7.889563e+00
# ACGATACTCAATCACG.1  7.083561e+00   5.324483681  -0.568869674 -9.163939e-01
# ACGATACTCAGTCCCT.1  4.041608e+00  10.693560404 -12.068046277  6.606256e+00
# ACGATACTCGAACTGT.1  2.099362e+01 -13.971449969   2.568341010 -1.020978e+00
# ACGATACTCGCAAACT.1  4.583416e+00  -9.127181619   1.998691854  1.406261e+00
# ACGATACTCTCGCATC.1 -2.357743e+00   1.779213308   7.326600724 -5.137167e+00
# ACGATGTAGCCATCGC.1  1.769143e+01   8.876055406  -8.785397021  8.355749e+00
# ACGATGTAGGAGCGAG.1 -1.804465e+01   1.855027864 -19.061318814 -3.014978e+00
# ACGATGTAGGGTCTCC.1  4.870276e+00 -12.303908496   2.684709903  7.329346e+00
# ACGATGTCAAGGTGTG.1  1.643232e+01 -10.882176446  10.279826524  1.070705e+01
# ACGATGTCACCTCGTT.1 -1.656559e+01  -4.341139199   8.782994164 -8.025065e+00
# ACGATGTCATGCCTTC.1  1.999212e+01   7.776568304   2.477325034  1.019519e+01
# ACGATGTGTCAAACTC.1  1.338551e+01 -15.272703528 -10.838076624  4.565438e+00
# ACGATGTGTCAGAAGC.1  6.019295e-01  -9.592531350  -0.237002025 -5.340997e-01
# ACGATGTGTTCAGCGC.1  9.384844e+00 -18.027942074  -5.836124466 -2.493083e+00
# ACGATGTGTTGAGGTG.1 -1.617212e+01  -5.861692832   7.027794528  1.285973e+01
# ACGATGTTCAGGCCCA.1 -2.485240e+00 -13.666204988  -1.284685230 -1.075936e+01
# ACGATGTTCGCAAGCC.1 -2.605045e+00 -11.136932228  10.149180600 -9.904784e-01
# ACGATGTTCGTTGACA.1 -1.794929e+01  -7.660388088   2.811595371 -5.085590e+00
# ACGATGTTCTCTGTCG.1 -7.635756e+00  23.525844135   5.908844856  4.353121e+00
# ACGCAGCAGCAACGGT.1 -2.151345e+01  -5.389837127   3.100731841  4.302173e-01
# ACGCAGCAGCCAGTAG.1  3.641108e+00   2.408814328   1.721013623 -1.261958e+00
# ACGCAGCCAAGTTAAG.1 -1.523672e+01   5.587120057   4.382855152 -6.485611e+00
# ACGCAGCCATCGTCGG.1  1.100047e+01  -6.379653095 -17.869659951  8.563006e+00
# ACGCAGCGTATAGTAG.1 -1.037968e+01  18.829745989  -0.922344549  1.452054e+01
# ACGCAGCGTATATGAG.1 -6.148715e+00 -11.792870075  -4.303384317 -5.604923e+00
# ACGCAGCGTATTCTCT.1 -2.252696e+00 -10.472833319   7.029223840  1.011133e+00
# ACGCAGCGTCAAGCGA.1  1.159157e+01   7.574676762   9.814269213  1.201074e+00
# ACGCAGCGTCAGAAGC.1  6.109707e+00  -0.911732761  12.884164969 -4.902389e+00
# ACGCAGCGTCCCTTGT.1 -2.022608e+01  -5.511580110   2.010287718 -1.290369e+01
# ACGCAGCTCAAACCGT.1  1.357639e+01   2.867799878   4.845870673  2.552476e+00
# ACGCAGCTCAGTGTTG.1  5.159033e+00   8.129651721  -7.615540603 -3.056832e+00
# ACGCAGCTCATCTGTT.1  3.171393e+01   4.850956030  11.597296245  4.441535e+00
# ACGCAGCTCTGCTTGC.1  2.207453e+01   6.559592082  -2.249957117  8.513138e+00
# ACGCCAGAGAGTGAGA.1 -1.110536e+01  19.169648628  -5.922654431  8.818348e+00
# ACGCCAGAGGCCCTCA.1 -1.351749e+01   7.320402612   1.579529470  1.092443e+00
# ACGCCAGAGGCTAGCA.1 -4.870494e+00   3.973467079   3.385794744  1.110633e+01
# ACGCCAGAGTGGGATC.1  6.552858e+00  15.493249357  11.983307113  4.823201e+00
# ACGCCAGCATACAGCT.1 -2.865397e+01  -3.421932930   7.180166527 -6.664040e-01
# ACGCCAGCATTCACTT.1  6.597085e+00  18.012933689   1.753929991  5.695108e+00
# ACGCCAGGTACATGTC.1  2.457931e+01   7.978789630   3.277424401 -3.487465e+00
# ACGCCAGGTGCAACGA.1 -1.036328e+00   9.854928350 -12.316637453 -2.931618e+00
# ACGCCAGGTTAAGTAG.1 -1.920333e+00  -8.821576097 -10.201321186 -1.013148e+01
# ACGCCAGGTTCCTCCA.1  1.544194e+01  -4.951699453 -16.272643018  1.497375e+00
# ACGCCAGGTTGGACCC.1  9.683981e+00  12.107274545   8.369244201 -1.599526e+00
# ACGCCAGTCGGCGGTT.1 -4.332533e+00  -8.475453334   3.495250762 -1.079463e+01
# ACGCCAGTCGGCTTGG.1 -2.412756e+01  -3.139493294  -6.432786937 -1.155266e+01
# ACGCCAGTCGTCCAGG.1  1.215435e+01 -17.995840919 -13.171569760  1.515706e+01
# ACGCCGAAGAGGGCTT.1 -3.509054e+00  -5.564343530  14.946791144 -7.935471e+00
# ACGCCGAAGATCGGGT.1 -9.883939e+00  -2.534613938   2.333861162 -1.064202e+01
# ACGCCGAAGCGATTCT.1 -2.217649e+01  13.253887243   1.295875831 -4.638117e-01
# ACGCCGAAGCTACCGC.1  9.051582e+00  -7.351197084  -9.560012389 -8.077210e+00
# ACGCCGAAGGGATACC.1 -1.474009e+01  15.480795589   0.578208575 -7.947445e+00
# ACGCCGAAGTAACCCT.1 -2.580416e+01 -13.680926660  10.272770634  1.740357e+01
# ACGCCGAAGTGGCACA.1  3.224336e+01 -14.831633545   6.579733212 -7.476305e+00
# ACGCCGACAAGCCGTC.1 -5.778302e+00 -10.053852473  12.898511914  7.649099e+00
# ACGCCGACACACTGCG.1 -1.461696e+01  -5.631744397   5.010483502 -9.210971e+00
# ACGCCGACACCCATGG.1  1.779223e+01   9.525934684  14.429961034  3.912842e+00
# ACGCCGACATCGGGTC.1  2.537345e+00 -10.111175683   9.630574403  4.436744e+00
# ACGCCGAGTAGCTCCG.1  3.614881e+01 -11.213907525   6.647764801 -1.057492e+00
# ACGCCGATCGCACTCT.1 -1.205080e+01  -5.671913568  -0.715947743  1.134048e+00
# ACGCCGATCTGGTGTA.1  1.064377e+01  -8.938783258   0.778074329 -7.426226e+00
# ACGCCGATCTTTAGTC.1 -6.712341e+00  20.832191806   2.094029855 -4.213550e+00
# ACGGAGAAGGATGGTC.1  1.216907e+01 -16.211692049   1.765882727  2.690296e+00
# ACGGAGAAGGTAGCCA.1 -9.682474e+00  -1.291827145  13.468192447  1.057221e+00
# ACGGAGACAAGGTGTG.1 -3.381595e+01  -3.794867046 -15.824627420 -1.044718e+01
# ACGGAGACAATGGAGC.1  1.613536e+01 -18.600973281 -20.225339612  1.668070e+00
# ACGGAGACACCGGAAA.1  1.878006e+01   8.839140672   2.129650515  1.062910e+00
# ACGGAGACATGTAGTC.1  2.073701e+01   3.970759115   7.762268977 -9.642870e+00
# ACGGAGAGTTTGACTG.1 -2.831883e+01  19.376345727   0.768071560  5.679317e+00
# ACGGAGATCAAGGCTT.1 -1.657828e+01  -6.417225123   6.236526231 -1.265175e+00
# ACGGAGATCACCGGGT.1 -2.966817e+01  11.857197962 -22.575034784 -4.979376e+00
# ACGGAGATCACGCATA.1  3.939990e+00 -11.067170783  -4.190554827 -1.136741e+00
# ...
# TGTGTTTCACACCGAC.1 TGTGTTTCACTAAGTC.1 TGTGTTTGTGCAGGTA.1 TGTGTTTGTTCTGGTA.1
#                  6                  3                  5                  2
# TGTGTTTTCACGAAGG.1 TGTGTTTTCGGAATCT.1 TGTGTTTTCGGTGTCG.1 TGTTCCGAGAAACCAT.1
#                  3                  4                  3                  3
# TGTTCCGAGAAACCGC.1 TGTTCCGAGACGCTTT.1 TGTTCCGAGGTGATTA.1 TGTTCCGAGTGAATTG.1
#                  3                  7                  5                  2
# TGTTCCGCACATTTCT.1 TGTTCCGCATTAACCG.1 TGTTCCGCATTAGGCT.1 TGTTCCGGTCATCGGC.1
#                  3                  1                  4                  2
# TGTTCCGGTTTGTTGG.1 TGTTCCGTCAACGGGA.1 TGTTCCGTCACCGGGT.1 TGTTCCGTCCACGAAT.1
#                  1                  7                  2                  1
# TGTTCCGTCCGTCATC.1 TGTTCCGTCGCATGAT.1 TGTTCCGTCGTCTGAA.1 TGTTCCGTCTTTAGGG.1
#                  2                  3                  6                  2
# TTAACTCAGAAGCCCA.1 TTAACTCAGTTCGATC.1 TTAACTCCAAACTGCT.1 TTAACTCCAAGGTGTG.1
#                  1                  3                  3                  6
# TTAACTCCACGAGAGT.1 TTAACTCCACGGCTAC.1 TTAACTCCACTGTTAG.1 TTAACTCCATACTCTT.1
#                  6                  6                  5                  1
# TTAACTCCATTGGCGC.1 TTAACTCGTCACACGC.1 TTAACTCGTGGCTCCA.1 TTAACTCGTGTGGCTC.1
#                  6                  7                  2                  2
# TTAACTCTCGGCTTGG.1 TTAGGACAGACCACGA.1 TTAGGACAGATGTGGC.1 TTAGGACAGCAATCTC.1
#                  6                  3                  1                  3
# TTAGGACCAAGTTGTC.1 TTAGGACCACAACGCC.1 TTAGGACCAGCTTAAC.1 TTAGGACCATTCTTAC.1
#                  3                  2                  7                  2
# TTAGGACGTGCACTTA.1 TTAGGACGTGGGTATG.1 TTAGGACGTGTCTGAT.1 TTAGGACTCACGACTA.1
#                  4                  3                  3                  5
# TTAGGCAAGAAACCTA.1 TTAGGCAAGAGGACGG.1 TTAGGCAAGATCTGCT.1 TTAGGCAAGCTCTCGG.1
#                  6                  3                  6                  7
# TTAGGCAAGGCACATG.1 TTAGGCAAGGCATGTG.1 TTAGGCACATCATCCC.1 TTAGGCACATGCATGT.1
#                  6                  7                  7                  4
# TTAGGCAGTAAATGAC.1 TTAGGCAGTACTCGCG.1 TTAGGCAGTCCTCTTG.1 TTAGGCAGTGTATGGG.1
#                  3                  5                  5                  1
# TTAGGCAGTGTGCGTC.1 TTAGGCAGTTATTCTC.1 TTAGGCAGTTGATTCG.1 TTAGGCATCACCATAG.1
#                  5                  6                  7                  6
# TTAGGCATCATGTGGT.1 TTAGGCATCTCTTATG.1 TTAGGCATCTGCGTAA.1 TTAGTTCAGAAGATTC.1
#                  3                  2                  5                  5
# TTAGTTCAGAATCTCC.1 TTAGTTCAGCAGATCG.1 TTAGTTCAGCCAGGAT.1 TTAGTTCAGTCACGCC.1
#                  3                  2                  7                  5
# TTAGTTCCAACTGCTA.1 TTAGTTCGTCCGAATT.1 TTAGTTCGTGCGAAAC.1 TTAGTTCGTGGTTTCA.1
#                  3                  2                  3                  2
# TTAGTTCTCCAAACTG.1 TTAGTTCTCCGAATGT.1 TTATGCTAGATCTGAA.1 TTATGCTAGTGCGTGA.1
#                  3                  5                  6                  4
# TTATGCTCAGACACTT.1 TTATGCTCATAGAAAC.1 TTATGCTGTAAATGTG.1 TTATGCTGTACTCGCG.1
#                  6                  2                  3                  3
# TTATGCTGTCGCTTTC.1 TTATGCTGTGAACCTT.1 TTATGCTGTGTGTGCC.1 TTATGCTGTTCAGGCC.1
#                  3                  1                  6                  3
# TTATGCTTCTCGCATC.1 TTATGCTTCTCGTATT.1 TTCCCAGAGACTGGGT.1 TTCCCAGAGTAGATGT.1
#                  4                  5                  6                  6
# TTCCCAGAGTCGCCGT.1 TTCCCAGCACGTTGGC.1 TTCCCAGCATAGGATA.1 TTCCCAGCATCGGGTC.1
#                  7                  3                  3                  5
# TTCCCAGGTACGACCC.1 TTCCCAGGTATGCTTG.1 TTCCCAGGTCCAAGTT.1 TTCCCAGGTGAAATCA.1
#                  3                  3                  6                  5
# TTCCCAGGTTCCGTCT.1 TTCCCAGTCAAGCCTA.1 TTCCCAGTCACGACTA.1 TTCCCAGTCAGCTCGG.1
#                  2                  6                  3                  5
# TTCCCAGTCCCTTGCA.1 TTCCCAGTCGCCATAA.1 TTCCCAGTCTTCGAGA.1 TTCGAAGAGACCACGA.1
#                  5                  3                  3                  1
# TTCGAAGAGATATACG.1 TTCGAAGAGGAATCGC.1 TTCGAAGAGTAGCCGA.1 TTCGAAGAGTCCCACG.1
#                  4                  3                  6                  7
# TTCGAAGCAGATTGCT.1 TTCGAAGCAGTATGCT.1 TTCGAAGGTATTCTCT.1 TTCGAAGGTCATCGGC.1
#                  5                  3                  5                  4
# TTCGAAGGTCTACCTC.1 TTCGAAGGTGTTTGTG.1 TTCGAAGTCCCATTAT.1 TTCGAAGTCTGTCTAT.1
#                  2                  2                  5                  6
# TTCGGTCAGAGCAATT.1 TTCGGTCAGCCCAATT.1 TTCGGTCAGTACATGA.1 TTCGGTCCACACAGAG.1
#                  6                  6                  3                  6
# TTCGGTCCAGATAATG.1 TTCGGTCCATGCCCGA.1 TTCGGTCGTACCGTTA.1 TTCGGTCGTCAACTGT.1
#                  6                  4                  4                  3
# TTCGGTCGTGGCTCCA.1 TTCGGTCTCCGCTGTT.1 TTCGGTCTCGGCATCG.1 TTCGGTCTCTCTGCTG.1
#                  1                  2                  4                  6
# TTCTACAAGACTAGAT.1 TTCTACAAGCAGCCTC.1 TTCTACAAGGCATGGT.1 TTCTACACACAAGACG.1
#                  2                  2                  2                  6
# TTCTACACACAGGAGT.1 TTCTACACACGGACAA.1 TTCTACACAGCGTCCA.1 TTCTACAGTCAGTGGA.1
#                  2                  6                  3                  7
# TTCTACAGTTGGACCC.1 TTCTACATCCGCGCAA.1 TTCTCAAAGATCGATA.1 TTCTCAAAGATCGGGT.1
#                  3                  2                  6                  7
# TTCTCAAAGCTGCCCA.1 TTCTCAAAGTCCATAC.1 TTCTCAACACCGAATT.1 TTCTCAACACGGCCAT.1
#                  7                  3                  1                  3
# TTCTCAACAGTATCTG.1 TTCTCAACATGACATC.1 TTCTCAAGTCAGAATA.1 TTCTCAAGTTACGACT.1
#                  6                  2                  3                  6
# TTCTCAAGTTCCGGCA.1 TTCTCAATCGCGGATC.1 TTCTCAATCTTGCAAG.1 TTCTCCTAGCCACGCT.1
#                  6                  1                  3                  4
# TTCTCCTAGCGATTCT.1 TTCTCCTCAACGCACC.1 TTCTCCTCATACGCCG.1 TTCTCCTCATTGGGCC.1
#                  3                  4                  3                  3
# TTCTCCTGTAGCGCTC.1 TTCTCCTGTCCCTACT.1 TTCTCCTGTCCCTTGT.1 TTCTCCTGTCTGGTCG.1
#                  6                  6                  8                  7
# TTCTCCTGTGTAATGA.1 TTCTCCTGTGTGAAAT.1 TTCTCCTGTTCAGTAC.1 TTCTCCTGTTCTGAAC.1
#                  2                  7                  2                  7
# TTCTCCTTCAACCAAC.1 TTCTCCTTCACGAAGG.1 TTCTCCTTCTGACCTC.1 TTCTCCTTCTGGTGTA.1
#                  6                  2                  4                  3
# TTCTCCTTCTTTACGT.1 TTCTTAGAGACCGGAT.1 TTCTTAGAGAGGACGG.1 TTCTTAGAGCCAACAG.1
#                  4                  6                  1                  5
# TTCTTAGAGCCAGAAC.1 TTCTTAGAGCTATGCT.1 TTCTTAGAGGGTGTTG.1 TTCTTAGAGTGTTAGA.1
#                  2                  2                  3                  6
# TTCTTAGCAAACCTAC.1 TTCTTAGCAAAGCGGT.1 TTCTTAGGTAGCCTAT.1 TTCTTAGGTCAATACC.1
#                  3                  6                  3                  4
# TTCTTAGGTCACACGC.1 TTCTTAGGTCAGAGGT.1 TTCTTAGGTTATCCGA.1 TTCTTAGGTTCAGACT.1
#                  2                  6                  2                  1
# TTCTTAGGTTGGGACA.1 TTCTTAGGTTTGACTG.1 TTCTTAGTCACAGGCC.1 TTCTTAGTCAGCTCTC.1
#                  6                  3                  3                  5
# TTCTTAGTCCCTCTTT.1 TTCTTAGTCCGAGCCA.1 TTCTTAGTCTGACCTC.1 TTCTTAGTCTTATCTG.1
#                  6                  5                  6                  4
# TTGAACGAGCCACGCT.1 TTGAACGAGGCGCTCT.1 TTGAACGAGTGTGAAT.1 TTGAACGCAGGGATTG.1
#                  4                  2                  3                  5
# TTGAACGCAGTGGAGT.1 TTGAACGGTATATGAG.1 TTGAACGGTTACCAGT.1 TTGAACGGTTTAGGAA.1
#                  2                  1                  6                  8
# TTGAACGTCACCACCT.1 TTGAACGTCATGGTCA.1 TTGAACGTCCAACCAA.1 TTGAACGTCGGTCTAA.1
#                  2                  2                  6                  2
# TTGACTTAGGCTCAGA.1 TTGACTTAGGTGATAT.1 TTGACTTAGTCGCCGT.1 TTGACTTAGTGAACGC.1
#                  3                  1                  6                  3
# TTGACTTCAATGAAAC.1 TTGACTTCAATTGCTG.1 TTGACTTCAGGTCGTC.1 TTGACTTGTACAAGTA.1
#                  4                  3                  3                  3
# TTGACTTGTCGGATCC.1 TTGACTTGTCTCTTTA.1 TTGACTTGTCTTCTCG.1 TTGACTTGTGGTCTCG.1
#                  1                  2                  3                  6
# TTGACTTGTTGCGCAC.1 TTGACTTTCAATCACG.1 TTGACTTTCCATGAGT.1 TTGACTTTCCTTGCCA.1
#                  4                  2                  3                  7
# TTGACTTTCGCGTAGC.1 TTGACTTTCGGAAATA.1 TTGACTTTCGGAATCT.1 TTGACTTTCGGCTACG.1
#                  3                  3                  4                  6
# TTGCCGTAGATCGGGT.1 TTGCCGTAGTAGGTGC.1 TTGCCGTCAAGGGTCA.1 TTGCCGTCACCACCAG.1
#                  5                  3                  5                  2
# TTGCCGTCACGGTGTC.1 TTGCCGTCATCACGTA.1 TTGCCGTGTATGAATG.1 TTGCCGTGTCAGAGGT.1
#                  6                  6                  3                  2
# TTGCCGTGTTCGCGAC.1 TTGCCGTTCATGTCCC.1 TTGCCGTTCCCTTGCA.1 TTGCCGTTCCTTCAAT.1
#                  1                  3                  5                  6
# TTGCGTCAGAGACTAT.1 TTGCGTCAGAGGACGG.1 TTGCGTCAGCAGGCTA.1 TTGCGTCAGCTGAACG.1
#                  6                  6                  4                  2
# TTGCGTCAGGAGCGTT.1 TTGCGTCAGGGAACGG.1 TTGCGTCAGTGTACTC.1 TTGCGTCCAACTTGAC.1
#                  6                  1                  6                  3
# TTGCGTCCAAGCGTAG.1 TTGCGTCCATCGGGTC.1 TTGCGTCGTAGCGCTC.1 TTGCGTCGTCCAAGTT.1
#                  7                  2                  4                  6
# TTGCGTCGTCCATGAT.1 TTGCGTCGTCGGCACT.1 TTGCGTCGTTCCACTC.1 TTGCGTCGTTGGTTTG.1
#                  6                  4                  2                  3
# TTGCGTCTCACCGTAA.1 TTGCGTCTCCTCTAGC.1 TTGCGTCTCGGTCCGA.1 TTGCGTCTCTGGCGTG.1
#                  2                  3                  2                  5
# TTGCGTCTCTGGTGTA.1 TTGCGTCTCTTCTGGC.1 TTGGAACAGAAGGACA.1 TTGGAACAGACGCAAC.1
#                  3                  2                  3                  2
# TTGGAACAGATAGTCA.1 TTGGAACAGCCACCTG.1 TTGGAACAGCTTCGCG.1 TTGGAACAGGTGACCA.1
#                  2                  1                  5                  2
# TTGGAACAGTTGTAGA.1 TTGGAACCAAAGCAAT.1 TTGGAACCACATTTCT.1 TTGGAACCACCTCGTT.1
#                  3                  5                  3                  3
# TTGGAACCACGACTCG.1 TTGGAACCAGGGATTG.1 TTGGAACGTCACACGC.1 TTGGAACGTCAGATAA.1
#                  3                  8                  5                  6
# TTGGAACGTCTAGCCG.1 TTGGAACTCAGTTGAC.1 TTGGAACTCATCATTC.1 TTGGAACTCGCATGAT.1
#                  1                  3                  6                  2
# TTGGAACTCGTCCGTT.1 TTGGCAAAGAATTGTG.1 TTGGCAAAGACACGAC.1 TTGGCAAAGAGATGAG.1
#                  6                  6                  3                  1
# TTGGCAAAGTAGCCGA.1 TTGGCAACACCTATCC.1 TTGGCAACACTTAACG.1 TTGGCAACATCGGACC.1
#                  2                  6                  6                  1
# TTGGCAAGTCTGCGGT.1 TTGGCAAGTGGGTCAA.1 TTGGCAAGTTTCCACC.1 TTGGCAATCACAAACC.1
#                  5                  3                  5                  7
# TTGGCAATCACCCGAG.1 TTGGCAATCATCACCC.1 TTGGCAATCCGGCACA.1 TTGTAGGAGGAGCGAG.1
#                  6                  2                  6                  2
# TTGTAGGAGGCCCGTT.1 TTGTAGGAGGGTTCCC.1 TTGTAGGCAAAGCGGT.1 TTGTAGGCAAGACACG.1
#                  7                  6                  1                  6
# TTGTAGGCAATGACCT.1 TTGTAGGCACAAGACG.1 TTGTAGGCAGTGGGAT.1 TTGTAGGGTACAAGTA.1
#                  4                  7                  2                  1
# TTGTAGGGTACACCGC.1 TTGTAGGGTCGAATCT.1 TTGTAGGGTTACAGAA.1 TTGTAGGGTTGACGTT.1
#                  4                  7                  6                  2
# TTGTAGGTCAACACGT.1 TTGTAGGTCAAGGCTT.1 TTGTAGGTCACAACGT.1 TTGTAGGTCTCCCTGA.1
#                  1                  2                  2                  6
# TTGTAGGTCTTATCTG.1 TTTACTGAGAGGTTAT.1 TTTACTGAGCGTAATA.1 TTTACTGAGCGTCTAT.1
#                  4                  5                  4                  5
# TTTACTGCACGAAGCA.1 TTTACTGGTTCGTGAT.1 TTTACTGTCCTCTAGC.1 TTTACTGTCTTTAGGG.1
#                  2                  3                  2                  1
# TTTATGCAGAAACGAG.1 TTTATGCAGATACACA.1 TTTATGCAGCTGAACG.1 TTTATGCAGGATGGAA.1
#                  1                  6                  5                  5
# TTTATGCAGTACGTAA.1 TTTATGCAGTATCGAA.1 TTTATGCAGTCCGTAT.1 TTTATGCAGTTTGCGT.1
#                  5                  3                  3                  5
# TTTATGCCACCATCCT.1 TTTATGCCACTAGTAC.1 TTTATGCCAGATAATG.1 TTTATGCCAGATTGCT.1
#                  3                  2                  2                  3
# TTTATGCCATCAGTAC.1 TTTATGCCATGACGGA.1 TTTATGCGTAGCGTAG.1 TTTATGCGTGACGGTA.1
#                  7                  2                  3                  5
# TTTATGCGTTACGACT.1 TTTATGCTCACTTATC.1 TTTATGCTCTCCTATA.1 TTTCCTCAGAGTAATC.1
#                  5                  3                  1                  2
# TTTCCTCAGCGTGAGT.1 TTTCCTCAGGCACATG.1 TTTCCTCAGGCTATCT.1 TTTCCTCAGTCACGCC.1
#                  3                  5                  2                  2
# TTTCCTCCAGCGATCC.1 TTTCCTCCAGTCAGCC.1 TTTCCTCGTCCAAGTT.1 TTTCCTCGTCGAACAG.1
#                  6                  4                  5                  5
# TTTCCTCTCCACGAAT.1 TTTCCTCTCGGTGTTA.1 TTTCCTCTCTCAAACG.1 TTTCCTCTCTCGGACG.1
#                  2                  5                  7                  7
# TTTGCGCAGATAGCAT.1 TTTGCGCCAAGACGTG.1 TTTGCGCCACCAGGTC.1 TTTGCGCCAGAGTGTG.1
#                  4                  6                  5                  4
# TTTGCGCCAGCCAATT.1 TTTGCGCCAGTCAGCC.1 TTTGCGCGTCATGCCG.1 TTTGCGCGTGATAAAC.1
#                  3                  5                  3                  5
# TTTGCGCGTGGTAACG.1 TTTGCGCTCAAACCAC.1 TTTGCGCTCATGCAAC.1 TTTGCGCTCCCTTGCA.1
#                  3                  6                  6                  3
# TTTGCGCTCCTCGCAT.1 TTTGCGCTCGCCAGCA.1 TTTGGTTAGATGTGGC.1 TTTGGTTAGGGTTTCT.1
#                  7                  1                  5                  3
# TTTGGTTAGGTGCACA.1 TTTGGTTCAAACAACA.1 TTTGGTTCAATTGCTG.1 TTTGGTTCACAGCCCA.1
#                  6                  5                  3                  1
# TTTGGTTCAGATAATG.1 TTTGGTTCAGTGGGAT.1 TTTGGTTCATGGGAAC.1 TTTGGTTGTAACGCGA.1
#                  6                  4                  3                  4
# TTTGGTTGTCTCTTAT.1 TTTGGTTTCAGATAAG.1 TTTGGTTTCCAAATGC.1 TTTGGTTTCCAAGCCG.1
#                  6                  2                  3                  5
# TTTGGTTTCCTAGGGC.1 TTTGGTTTCCTGCTTG.1 TTTGTCAAGAAGAAGC.1 TTTGTCAAGACCACGA.1
#                  3                  6                  7                  2
# TTTGTCAAGATAGGAG.1 TTTGTCAAGCGTGTCC.1 TTTGTCAAGGCAGGTT.1 TTTGTCAAGTACTTGC.1
#                  5                  2                  5                  3
# TTTGTCACAAATCCGT.1 TTTGTCACACAAGTAA.1 TTTGTCACATCTCGCT.1 TTTGTCACATGCAATC.1
#                  3                  5                  5                  3
# TTTGTCAGTAAATGAC.1 TTTGTCAGTCATATGC.1 TTTGTCAGTTCGCTAA.1 TTTGTCATCAGGTTCA.1
#                  7                  4                  7                  6
# TTTGTCATCCACTGGG.1 TTTGTCATCCTAAGTG.1 TTTGTCATCGCCTGAG.1 TTTGTCATCTCAAACG.1
#                  6                  1                  6                  2
# TTTGTCATCTGTCTAT.1 TTTGTCATCTTCTGGC.1
#                  7                  3
#
# $clucenter
#            [,1]       [,2]       [,3]       [,4]
# [1,]  10.937614   5.540112   4.673467  6.8895985
# [2,] -10.780403  -4.931833  -2.134862  0.7983979
# [3,]  -6.125500  -5.895849   3.379046 -5.5831361
# [4,]  11.270972 -11.455323 -10.634231  3.8502118
# [5,]  12.901614  12.312716   7.643321  0.2847848
# [6,]   1.058258   9.231472  -8.214978 -2.5337837
# [7,]  -3.852580  -9.226623  11.416252  3.4769247
# [8,] -22.070327   6.211846  -8.056462 21.1981057

# %% [markdown]
# ### TSCAN was not very useful

# %% [markdown]
# # Get markers from SC3 for each cluster

# %%
# %%R
#
# ###
# library(SingleCellExperiment)
# library(scater)
# library(SC3)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata <- readRDS("scater/sc3_clustered.rds")

# %%
# %%R
# #####write all results
# sc3_export_results_xls(scdata, filename = "scater/sc3_exported_results.xls")

# %%
# %%R
# #####write gene names, for manual excel analysis
# write.table(data.frame(rowData(scdata)$feature_symbol), file="scater/genes.tsv", sep='\t')

# %% [markdown]
# # Feature Selection for heatmap

# %%
# %%R
#
# ####clean data for M3Drop
# library(scRNA.seq.funcs)
# library(matrixStats)
# library(M3Drop)
# library(RColorBrewer)
# set.seed(1)
#
#
# scdata <- readRDS("scater/sc3_clustered.rds")
# cellLabels <- colData(scdata)$sc3_10_clusters
#
# scdata_list <- M3DropCleanData(
#     counts(scdata),
#     labels = cellLabels,
#     is.counts = TRUE
# )
#
# ####data formatting
# expr_matrix <- scdata_list$data # Normalized & filtered expression matrix
# celltype_labs <- factor(scdata_list$labels) # filtered cell-type labels
# cell_colors <- brewer.pal(max(10,length(unique(celltype_labs))), "Set3")
#
# print(dim(counts(scdata)))
# print(dim(expr_matrix))

# %%
# %%R
#
# ####find DE features using highly variable gene model (Brennecke)
# Brennecke_HVG <- BrenneckeGetVariableGenes(
#     expr_matrix,
#     fdr = 0.01,
#     minBiolDisp = 0.5
# )
#
# ####plot HVG results
# M3DropExpressionHeatmap(
#     Brennecke_HVG,
#     expr_matrix,
#     cell_labels = celltype_labs
# )

# %%
# %%R
# ####fitted to MM plot, different method
# M3Drop_genes <- M3DropDifferentialExpression(
#     expr_matrix,
#     mt_method = "fdr",
#     mt_threshold = 0.01
# )
#
# ####plot HVG results
# M3DropExpressionHeatmap(
#     M3Drop_genes,
#     expr_matrix,
#     cell_labels = celltype_labs
# )

# %%
# %%R
#
# ##########################overlay with SC3 clusters
#
# ####clean data for M3Drop
# library(scRNA.seq.funcs)
# library(matrixStats)
# library(M3Drop)
# library(RColorBrewer)
# set.seed(1)
#
#
# scdata <- readRDS("scater/sc3_clustered.rds")
# cellLabels <- colData(scdata)$sc3_10_clusters
#
# scdata_list <- M3DropCleanData(
#     counts(scdata),
#     labels = cellLabels,
#     is.counts = TRUE
# )
#
# ####data formatting
# expr_matrix <- scdata_list$data # Normalized & filtered expression matrix
# celltype_labs <- factor(scdata_list$labels) # filtered cell-type labels
# cell_colors <- brewer.pal(max(3,length(unique(celltype_labs))), "Set3")
#
# print(dim(counts(scdata)))
# print(dim(expr_matrix))
#
# ####find DE features using highly variable gene model (Brennecke)
# Brennecke_HVG <- BrenneckeGetVariableGenes(
#     expr_matrix,
#     fdr = 0.02,
#     minBiolDisp = 0.5
# )
#
# ####plot HVG results
# M3DropExpressionHeatmap(
#     Brennecke_HVG,
#     expr_matrix,
#     cell_labels = celltype_labs
# )

# %%
# %%R
#
# print(length(Brennecke_HVG))
# print(dim(M3Drop_genes))

# %%
# %%R
# mydata = Brennecke_HVG
# write.table(mydata, "scater/filtered_HVG.txt", sep="\t")
# mydata = M3Drop_genes
# write.table(mydata, "scater/filtered_M3Drop_genes.txt", sep="\t")

# %% [markdown]
# # Cluster separately - P, LVM1, LVM2

# %% [markdown]
# # THIS FILE MOVED OVER TO PIPELINE 2 FOR VISUALIZATION
# ### "scater/separately_clustered/sc3_clustered_P.rds"
# ### "scater/separately_clustered/sc3_clustered_LVM1.rds"
# ### "scater/separately_clustered/sc3_clustered_LVM2.rds"

# %%
# %%R
#
# ###
# library(SingleCellExperiment)
# library(scater)
# library(SC3)
# options(stringsAsFactors = FALSE)
# ###readin
# scdata <- readRDS("scater/ready_for_clustering.rds")
# #####subset in preparation for separate clustering
# P <- scdata[ , colData(scdata)$sample == "Parent"]
# LVM1 <- scdata[ , colData(scdata)$sample == "Lvm1"]
# LVM2 <- scdata[ , colData(scdata)$sample == "Lvm2"]
# #####run TSNE separately
# P <- runTSNE(P,exprs_values='logcounts',perplexity = 30,rand_seed = 10000)
# LVM1 <- runTSNE(LVM1,exprs_values='logcounts',perplexity = 30,rand_seed = 10000)
# LVM2 <- runTSNE(LVM2,exprs_values='logcounts',perplexity = 30,rand_seed = 10000)
#
# #####note, the code below is just factored for each dataset (P, LVM1, LVM2)
#
# ##############
# ########cluster P
# ##############
# scdata <- P
# #####
# rowData(scdata)$feature_symbol <-rownames(scdata)
# ####cluster
# scdata <- sc3(scdata, ks = 2:10, biology = TRUE,n_cores=16)
# ####estimate optimal cluster size
# scdata <- sc3_estimate_k(scdata)
# print(metadata(scdata)$sc3$k_estimation)
# ###save file
# saveRDS(scdata, file = "scater/separately_clustered/sc3_clustered_P.rds")
#
# ##############
# ########cluster LVM1
# ##############
# scdata <- LVM1
# #####
# rowData(scdata)$feature_symbol <-rownames(scdata)
# ####cluster
# scdata <- sc3(scdata, ks = 2:10, biology = TRUE,n_cores=16)
# ####estimate optimal cluster size
# scdata <- sc3_estimate_k(scdata)
# print(metadata(scdata)$sc3$k_estimation)
# ###save file
# saveRDS(scdata, file = "scater/separately_clustered/sc3_clustered_LVM1.rds")
#
# ##############
# ########cluster LVM2
# ##############
# scdata <- LVM2
# #####
# rowData(scdata)$feature_symbol <-rownames(scdata)
# ####cluster
# scdata <- sc3(scdata, ks = 2:10, biology = TRUE,n_cores=16)
# ####estimate optimal cluster size
# scdata <- sc3_estimate_k(scdata)
# print(metadata(scdata)$sc3$k_estimation)
# ###save file
# saveRDS(scdata, file = "scater/separately_clustered/sc3_clustered_LVM2.rds")
# Out:
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Setting SC3 parameters...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Your dataset contains more than 2000 cells. Adjusting the nstart parameter of kmeans to 50 for faster performance...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Calculating distances between the cells...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Performing transformations and calculating eigenvectors...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Performing k-means clustering...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Calculating consensus matrix...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Calculating biology...
#
#   warnings.warn(x, RRuntimeWarning)
# /home/johnny/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Estimating k...
#
#   warnings.warn(x, RRuntimeWarning)
# [1] 21
#
# [1] 17
#
# [1] 19

# %% [markdown]
# # Process in python

# %%
# %%R
#
# write.csv(head(assays(scdata.qc,"combat")),'combat.tsv',sep='\t')

# %%
# %%R
#
# normcounts(scdata.qc) <- assays(scdata.qc,"combat")
#
# write.csv(head(normcounts(scdata.qc)),'after.tsv',sep='\t')

# %%
def print_cluster4_genevals(gene,cluster4_index):
####
    cluster4 = []
    for num in cluster4_index:
        name = 'cell_'+num
        cluster4.append(expr[name].loc[gene])
    ####
    print('cluster4',np.average(cluster4))
    print(len(cluster4))
    ####
    cluster_total = list(expr.columns)
    cluster_not = list(cluster_total)
    # print(cluster_total)
    for cell in cluster_total:
    #     print("dddddd",cell)
        for num in cluster4_index:
            name = 'cell_'+num
    #         print(name)
            if cell == name:
                cluster_not.remove(cell)
    #             print('removed',cell)
    # print(cluster_not)
    ####
    cluster4_not = []
    for cell in cluster_not:
        cluster4_not.append(expr[cell].loc[gene])
    ####
    print('cluster4_not',np.average(cluster4_not))
    print(len(cluster4_not))
    ############ttest
    results = stats.ttest_ind(cluster4,cluster4_not,nan_policy='omit')
    print(results)

# %%
#####look at gene EGFR
os.system('mkdir sufam')
###
def cmd_extract_reads(loc, filename):
    folder = filename[24:26]
    cmd = 'samtools view -bh ../B_G_'+folder+'/'+filename+' '+loc+' > EGFR.'+filename
    return(os.system(cmd))
def cmd_index(filename):
    cmd = 'samtools index '+filename
    return(os.system(cmd))
def cmd_tofasta(filename):
    cmd = 'samtools fasta '+filename+' > '+filename+'.fa'
    return(os.system(cmd))
def cmd_sufam(filename):
    cmd = 'sufam /avicenna/genomes/hg38_2/hg38.fa mutations.vcf '+filename+' 2> sufam/'+filename+'.log > sufam/'+filename+'.tsv'
    return(os.system(cmd))
expr = pd.read_csv("scater/filtered_exprs_edited.txt", sep=',',index_col = 0)
####
cluster3_index = ['4','5','9','10','38']
gene = 'ENSG00000146648'
####
print_cluster3_genevals(gene,cluster3_index)

####pull out EGFR exon 21 reads from bam files
loc = "chr7:55191822"
###
files = pd.read_csv("scater/filtered_file.txt", sep= '\t', index_col = 0)
files = list(files['x'])
###
# for name in files:
#     cmd_extract_reads(loc,name)
#     cmd_index('EGFR.'+name)
#     cmd_tofasta('EGFR.'+name)
#     cmd_sufam('EGFR.'+name)

# %%
####process mutation data
df_files = pd.DataFrame(files)
df_files.index = files
###
files_sufam = []
for name in files:
    files_sufam.append('sufam/EGFR.'+name+'.tsv')
df_files['sufam'] = files_sufam
###
df_files.drop(0,axis=1,inplace=True)
###
sufam_out = pd.read_csv(df_files['sufam'][18],sep='\t',index_col = 0)
for i in range(len(df_files['sufam'])):
    if i != 0:
        temp = pd.read_csv(df_files['sufam'][i],sep='\t',index_col = 0)
        sufam_out = sufam_out.append(temp)
sufam_out

table_cell = pd.read_csv('scater/filtered_file_edited.csv',sep=',',index_col=0)
mutation = sufam_out.merge(table_cell,left_index=True,right_index=True)
mutation.to_csv('sufam/mutations.out',sep='\t')
mutation = mutation[mutation['cov']>1][['cell','cov','val_maf']]
mutation.to_csv('sufam/mutations.filtered.out',sep='\t')

# %%
# #####compare alignment
# from Bio import SeqIO
# from Bio import pairwise2
# ####refseq is normal
# ref_seq = "TTTTGGGCTGGCCAA"
# ####format seqs for comparison
# files_fa = []
# for name in files:
#     files_fa.append('EGFR.'+name+'.fa')
# ###
# seqs = []
# for record in SeqIO.parse(files_fa[0], "fasta"):
#     seqs.append(record.seq)
# ####
# for seq in seqs:
#     print pairwise2.align.globalxx(ref_seq, seq)

# %%
#####look at gene myc
expr = pd.read_csv("scater/filtered_exprs_edited.txt", sep=',',index_col = 0)
####
cluster3_index = ['4','5','9','10','38']
gene = 'ENSG00000136997'
####
print_cluster3_genevals(gene,cluster3_index)

# %%
#####look at gene tp53
expr = pd.read_csv("scater/filtered_exprs_edited.txt", sep=',',index_col = 0)
####
cluster3_index = ['4','5','9','10','38']
gene = 'ENSG00000141510'
####
print_cluster3_genevals(gene,cluster3_index)

# %%
#####look at gene stat3
expr = pd.read_csv("scater/filtered_exprs_edited.txt", sep=',',index_col = 0)
####
cluster3_index = ['4','5','9','10','38']
gene = 'ENSG00000168610'
####
print_cluster3_genevals(gene,cluster3_index)

# %%
#####look at gene ccnd1
expr = pd.read_csv("scater/filtered_exprs_edited.txt", sep=',',index_col = 0)
####
cluster3_index = ['4','5','9','10','38']
gene = 'ENSG00000110092'
####
print_cluster3_genevals(gene,cluster3_index)

# %%
####this is the egfr expression across cells
expr = pd.read_csv("scater/filtered_exprs.txt", sep='\t',index_col = 0)
# expr.loc['ENSG00000146648']

# %%
####matching HVG list
HVG = pd.read_csv("scater/filtered_HVG.txt", sep='\t',index_col = 1)
HVG.columns = [['rank']]
###
ENS = pd.read_csv("ensmbl_proteincoding.txt", sep='\t',index_col = 0)
HVG = HVG.merge(ENS,left_index = True, right_index = True)
HVG.columns = [['rank','name']]
###save
HVG.to_csv('scater/filtered_matched_HVG.txt', sep='\t')

# %% [markdown]
# # Analyze using SCDE

# %%
# %%R
#
# library(scRNA.seq.funcs)
# library(matrixStats)
# library(M3Drop)
# library(RColorBrewer)
# library(scde)
# set.seed(1)
#
# ####readin data
# scdata <- readRDS("scater/filtered_3_sc3.rds")
#
# scdata

# %%
# %%R
#
# #####format
# test <- apply(
#     counts(scdata),
#     2,
#     function(x) {
#         storage.mode(x) <- 'integer'
#         return(x)
#     }
# )
#
# x <- colData(scdata)$sc3_4_clusters
#
# l2cols <- c("coral4", "olivedrab3", "skyblue2", "cornsilk")[as.integer(factor(x, levels = c("1", "2", "3","4")))]
#
# ###run error modelling
#
# knn <- knn.error.models(test, k = ncol(test)/4, n.cores = 4, min.count.threshold = 2, min.nonfailed = 5, max.model.plots = 10)
#
# varinfo <- pagoda.varnorm(knn, counts = test, trim = 2/ncol(test), max.adj.var = 5, n.cores = 4, plot = TRUE)
#
# varinfo <- pagoda.subtract.aspect(varinfo, colSums(test[, rownames(knn)]>0))
#
# ####run gene sets analysis
#
# library(org.Hs.eg.db)
#
# ids <- unlist(lapply(mget(rownames(test), org.Hs.egENSEMBL2EG, ifnotfound = NA), function(x) x[1]))
# rids <- names(ids); names(rids) <- ids
# gos.interest <- unique(c(ls(org.Hs.egGO2ALLEGS)))
# go.env <- lapply(mget(gos.interest, org.Hs.egGO2ALLEGS), function(x) as.character(na.omit(rids[x])))
# go.env <- clean.gos(go.env) # remove GOs with too few or too many genes
# go.env <- list2env(go.env) # convert to an environment
#
# #### pagoda
#
# pwpca <- pagoda.pathway.wPCA(varinfo, go.env, n.components = 1, n.cores = 4)
#
# png(filename = "1.png")
# df <- pagoda.top.aspects(pwpca, return.table = TRUE, plot = TRUE, z.score = 1.96)
# dev.off()
#
# head(df)
#
# write.table(df, file = "scde/gsea_GO.txt", row.names = TRUE, col.names = TRUE, sep = "\t", quote = FALSE)
#
# png(filename = "2.png")
# clpca <- pagoda.gene.clusters(varinfo, trim = 7.1/ncol(varinfo$mat), n.clusters = 50, n.cores = 4, plot = TRUE)
# dev.off()
#
# png(filename = "3.png")
# df <- pagoda.top.aspects(pwpca, clpca, return.table = TRUE, plot = TRUE, z.score = 1.96)
# dev.off()
#
# write.table(df, file = "scde/gsea_deNovo.txt", row.names = TRUE, col.names = TRUE, sep = "\t", quote = FALSE)
#
# ######visualize
#
# tam <- pagoda.top.aspects(pwpca, clpca, n.cells = NULL, z.score = qnorm(0.01/2, lower.tail = FALSE))
#
# hc <- pagoda.cluster.cells(tam, varinfo)
#
# tamr <- pagoda.reduce.loading.redundancy(tam, pwpca, clpca)
#
# png(filename = "4.png")
# tamr2 <- pagoda.reduce.redundancy(tamr, distance.threshold = 0.9, plot = TRUE, cell.clustering = hc, labRow = NA, labCol = NA, box = TRUE, margins = c(0.5, 0.5), trim = 0)
# col.cols <- rbind(groups = cutree(hc, 4))
# pagoda.view.aspects(tamr2, cell.clustering = hc, box = TRUE, labCol = NA, margins = c(0.5, 20), col.cols = rbind(l2cols))
# dev.off()
#
# png(filename = "5.png")
# pagoda.view.aspects(tamr2, cell.clustering = hc, row.clustering = NA, box = TRUE, labCol = NA, margins = c(0.5, 20), col.cols = rbind(l2cols))
# dev.off()

# %%
# %%R
#
# save(file="121417.RData")

# %%
# %%R
#
# ##pull out individual genes
#
# pagoda.show.pathways(c("GO:0000982"), varinfo, go.env, cell.clustering = hc, margins = c(1,5), show.cell.dendrogram = TRUE, showRowLabels = TRUE, showPC = TRUE)

# %%
# %%R
#
# ##pull out individual genes
# test.pattern <- pagoda.show.pathways(c("GO:0052695"), varinfo, go.env, show.cell.dendrogram = TRUE, cell.clustering = hc, showRowLabels = TRUE)
#
# varinfo.test <- pagoda.subtract.aspect(varinfo, test.pattern)

# %%
# %%R
#
# table(clpca$clusters$geneCluster.22)

# %%
pagoda.view.aspects(tamr2, cell.clustering = hc, row.clustering = NA, box = TRUE, labCol = NA, margins = c(0.5, 20), col.cols = rbind(l2cols))
